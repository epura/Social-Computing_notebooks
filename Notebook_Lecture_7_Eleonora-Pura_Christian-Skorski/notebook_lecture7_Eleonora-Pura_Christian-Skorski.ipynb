# %% [markdown]
# # Using APIs

# %% [markdown]
# <p>Pair answering the assignment: <b>Eleonora Pura, Christian Skorski</b></p>
#     <p>Pair giving feedback: <b>Dominik Frauchiger, David Steiger, Tim Moser</b></p>

# %%
import requests
import json
import os

# %% [markdown]
# ## 1. Google books
# ### Setting the request URL parameters
# You can set the parameters of the API request according to the documentation below. The first part of the request is always the same, and the "q" which stands for question will take various parameters. <br>
# More documentation can be found at: https://developers.google.com/books/docs/v1/using?hl=vi#ids
#
# <img src="parameters.png" width=80%> </img>

# %% [markdown]
# **Example**: `https://www.googleapis.com/books/v1/volumes?q=isbn:9780141909882` returns information about the book with the given ISBN number (Everything is illuminated by Jonathan Safran Foer).

# %% [markdown]
# **Exercise**
#
# 1. Using the above parameters create the following request URLs!
#     1. Requesting books that have "potter" in the title
#     2. Requesting books that have "doyle" as author
#     3. With isbn "1904633684"
#     4. With id "2bGdK8CRKoEC"
#     5. Second result page when searching books that has "detective" listed in the category list
#     6. Second result page when searching books that have "potter in the title but showing 40 results in one page, not 10.
# <br>
#
# Try and see whether they work with `requests.get()`!

# %%
result_A = "https://www.googleapis.com/books/v1/volumes?q=intitle:potter"
result_B = "https://www.googleapis.com/books/v1/volumes?q=author:doyle"
result_C = "https://www.googleapis.com/books/v1/volumes?q=isbn:1904633684"
result_D = "https://www.googleapis.com/books/v1/volumes?q=id:2bGdK8CRKoEC"
result_E = "https://www.googleapis.com/books/v1/volumes?q=insubject:detective&startIndex=10"
result_F = "https://www.googleapis.com/books/v1/volumes?q=intitle:potter&maxResults=40"

#check with requests

print(requests.get(result_A).text)
print(requests.get(result_B).text)
print(requests.get(result_C).text)
print(requests.get(result_D).text)
print(requests.get(result_E).text)
print(requests.get(result_F).text)

#continue to check all your URLs this way!
# Out:
# {
#  "kind": "books#volumes",
#  "totalItems": 498,
#  "items": [
#   {
#    "kind": "books#volume",
#    "id": "e5XGeVw23O8C",
#    "etag": "SA4ej2hpklw",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/e5XGeVw23O8C",
#    "volumeInfo": {
#     "title": "Harry Potter - ein Literatur- und Medienereignis im Blickpunkt interdisziplinärer Forschung",
#     "authors": [
#      "Christine Garbe"
#     ],
#     "publisher": "LIT Verlag Münster",
#     "publishedDate": "2006",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "3825872424"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9783825872427"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 326,
#     "printType": "BOOK",
#     "categories": [
#      "Children's stories, English"
#     ],
#     "averageRating": 1.0,
#     "ratingsCount": 1,
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "2.1.2.0.preview.1",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=e5XGeVw23O8C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=e5XGeVw23O8C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=e5XGeVw23O8C&printsec=frontcover&dq=intitle:potter&hl=&cd=1&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=e5XGeVw23O8C&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=e5XGeVw23O8C"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 21.47,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 14.6,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=e5XGeVw23O8C&rdid=book-e5XGeVw23O8C&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 2.147E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 1.46E7,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": true
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=e5XGeVw23O8C&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "ovN4WwnW_BsC",
#    "etag": "8Xx3OAalAKg",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/ovN4WwnW_BsC",
#    "volumeInfo": {
#     "title": "Die Philosophie bei Harry Potter",
#     "authors": [
#      "Gregory Bassham"
#     ],
#     "publisher": "John Wiley & Sons",
#     "publishedDate": "2010",
#     "description": "Der große Kampf ist vorbei. Das Gute hat gesiegt und so ist es nun an der Zeit innezuhalten, um einen Blick auf eines der bedeutendsten literarischen Phänomene unserer Zeit zu werfen und zu erkennen welche Magie hinter den unsterblichen Büchern von Joanne K. Rowling steckt. Die Philosophie bei Harry Potter zeigt, dass viel mehr in den mehr als 5000 Seiten und bald 8 Filmen über den kleinen Zauberlehrling steckt, als man mit bloßem Auge beim ersten Lesen erfassen kann. Und daher rührt schließlich auch der große Erfolg der Bücher und Filme, die nicht nur Kinder und Jugendliche sondern Erwachsene gleichermaßen faszinieren. Selbst die Großen Zauberer an den Universitäten befanden Harry Potter, seine Entwicklung und seine Abenteuer würdig, um sich damit zu beschäftigen. Was sie darin fanden, waren große Ideen und Erkenntnisse über alle wichtigen Dinge, die uns das Leben lehrt: Mut, Freundschaft, Gerechtigkeit, Liebe und Ehrgeiz verbinden sich mit der Frage nach Gut und Böse, Freiheit und Tod. So erweist sich Joanne K. Rowling nicht nur als eine großartige Geschichtenerzählerin, sondern beschäftigt sich durchaus mit Konzepten, die unser Leben jeden Tag aufs Neue bestimmen. *Was ist Liebe und warum gilt sie als mächtigster Zauber der Welt? *Was treibt die Mächtigen wie Dumbledore oder Lucius Malfoy an? *Was ist Realität - was Illusion? *Genießen die kleinen Zauberer im Zauberinternat eine gute Erziehung? *Ist es wirklich wie Dumbledore sagt, dass unsere Entscheidungen viel mehr über uns verraten als unsere Fähigkeiten?",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783527505715"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3527505717"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 293,
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "0.4.4.0.preview.1",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=ovN4WwnW_BsC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=ovN4WwnW_BsC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=ovN4WwnW_BsC&printsec=frontcover&dq=intitle:potter&hl=&cd=2&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=ovN4WwnW_BsC&dq=intitle:potter&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Die_Philosophie_bei_Harry_Potter.html?hl=&id=ovN4WwnW_BsC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=ovN4WwnW_BsC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Die Philosophie bei Harry Potter zeigt, dass viel mehr in den mehr als 5000 Seiten und bald 8 Filmen über den kleinen Zauberlehrling steckt, als man mit bloßem Auge beim ersten Lesen erfassen kann."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "B2geae4-FGEC",
#    "etag": "Go0eEeBV9Yo",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/B2geae4-FGEC",
#    "volumeInfo": {
#     "title": "Faszination \"Harry Potter\": Was steckt dahinter?",
#     "authors": [
#      "Detlev Dormeyer"
#     ],
#     "publisher": "LIT Verlag Münster",
#     "publishedDate": "2005",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "3825876446"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9783825876449"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 119,
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "2.1.5.0.preview.1",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=B2geae4-FGEC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=B2geae4-FGEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=B2geae4-FGEC&printsec=frontcover&dq=intitle:potter&hl=&cd=3&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=B2geae4-FGEC&dq=intitle:potter&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Faszination_Harry_Potter_Was_steckt_dahi.html?hl=&id=B2geae4-FGEC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": true
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=B2geae4-FGEC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "HtIZqdbqcUYC",
#    "etag": "jWfyk9aDfME",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/HtIZqdbqcUYC",
#    "volumeInfo": {
#     "title": "Harry Potter entzaubert - eine Analyse",
#     "publisher": "epubli",
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=HtIZqdbqcUYC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=HtIZqdbqcUYC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=HtIZqdbqcUYC&printsec=frontcover&dq=intitle:potter&hl=&cd=4&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=HtIZqdbqcUYC&dq=intitle:potter&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_entzaubert_eine_Analyse.html?hl=&id=HtIZqdbqcUYC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=HtIZqdbqcUYC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "WVr14222cw4C",
#    "etag": "GDewvBptWOo",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/WVr14222cw4C",
#    "volumeInfo": {
#     "title": "Religiöse Elemente in Harry Potter",
#     "authors": [
#      "Nicole Muermann"
#     ],
#     "publisher": "GRIN Verlag",
#     "publishedDate": "2006-12-14",
#     "description": "Examensarbeit aus dem Jahr 2006 im Fachbereich Theologie - Didaktik, Religionspädagogik, Note: 2,7, Technische Universität Dortmund, 23 Quellen im Literaturverzeichnis, Sprache: Deutsch, Abstract: In dieser Arbeit werden die gegensätzlichen Meinungen zu den Harry-Potter-Romanen wissenschaftlich aufgezeigt und untersucht. Um die verschiedenen Standpunkte genauer betrachten zu können und wissenschaftlich mit ihnen umzugehen, werden zunächst die Harry-Potter-Romane inhaltlich zusammengefasst. Anschließend soll der religionspädagogische Diskussionsstoff zum Thema dargestellt und aufgegriffen werden. Hier wird man eine Darstellung der gegensätzlichen Meinungen zum religiösen Inhalt der Harry-Potter-Romane finden. Anschließend werden eigene Bewertungen der Harry-Potter-Reihe begründet darstellen. Hier findet man sowohl eine Definition von Religion und religiös, als auch die Wertung der Geschichte in Bezug auf Nutzen und Gefahr für Kinder und Jugendliche. Nach dieser Darstellung wird die Frage nach Anknüpfungspunkten für den Religionsunterricht in den Romanen gestellt und es werden einige Beispiele für die Umsetzung der Geschichten im Unterricht gegeben. Abschließend wird die Arbeit mit einem Fazit, welches die wichtigsten Ergebnisse noch einmal zusammenfasst und die persönliche Meinung zu dem Thema darstellt, beendet.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783638580236"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3638580237"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 63,
#     "printType": "BOOK",
#     "categories": [
#      "Religion"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "2.13.7.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=WVr14222cw4C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=WVr14222cw4C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=WVr14222cw4C&printsec=frontcover&dq=intitle:potter&hl=&cd=5&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=WVr14222cw4C&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=WVr14222cw4C"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 24.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 16.8,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=WVr14222cw4C&rdid=book-WVr14222cw4C&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 2.4E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 1.68E7,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Religi%C3%B6se_Elemente_in_Harry_Potter-sample-epub.acsm?id=WVr14222cw4C&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Religi%C3%B6se_Elemente_in_Harry_Potter-sample-pdf.acsm?id=WVr14222cw4C&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=WVr14222cw4C&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Examensarbeit aus dem Jahr 2006 im Fachbereich Theologie - Didaktik, Religionspädagogik, Note: 2,7, Technische Universität Dortmund, 23 Quellen im Literaturverzeichnis, Sprache: Deutsch, Abstract: In dieser Arbeit werden die ..."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "bScqAQAAIAAJ",
#    "etag": "gR6dHCR3cY8",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/bScqAQAAIAAJ",
#    "volumeInfo": {
#     "title": "Kulturphänomen Harry Potter",
#     "subtitle": "Multiadressiertheit und Internationalität eines nationalen Literatur- und Medienevents",
#     "authors": [
#      "Ina Karg",
#      "Iris Mende"
#     ],
#     "publisher": "Vamp;R Unipress Gmbh",
#     "publishedDate": "2010-01-21",
#     "description": "English summary: The hype about J.K. Rowlings' sensationally successful series has since quieted down. From a certain distance, the many aspects of an event like the Harry Potter craze cannot be fully appreciated, but one can pursue the question how it came about that a literary work of several thousand pages was able to find a global readership although the cultural setting of this epic world is more specifically national than almost any other in world literature. A look at the public discourse, particularly around the time the last volume was released, sheds light on conceptions and expectations of literature. Above all, the texts themselves are examined, different readings are sounded out, and links are pursued to really understand the existing phenomena, literary motives, characters, traditions and narrative styles. Harry Potter surpasses all boundaries: those of language, markets, target groups, literary genres and traditions. At the same time, the multifaceted vision which the Harry Potter series necessitates signifies the need for a revision at least of conventional literary studies. German description: Inzwischen ist es um J. K. Rowlings Erfolgsserie vergleichsweise ruhig geworden. Aus einer gewissen Distanz heraus kann ein Ereignis wie Harry Potter zwar nicht in seiner ganzen Vielfalt gewurdigt werden. Jedoch kann der Frage nachgegangen werden, wie ein literarisches Werk von vielen tausend Seiten eine weltweite Leserschaft findet, wo doch der Ort des Geschehens dieser epischen Welt so kulturspezifisch-national ist wie kaum ein anderer in der gesamten Weltliteratur. Der Blick auf den offentlichen Diskurs vor allem bei Erscheinen des letzten Bandes gibt dabei Aufschluss uber die Auffassungen von und Erwartungen an Literatur. Der Blick richtet sich aber vor allem auf die Texte selbst, lotet Lesarten aus und folgt Verweislinien zu real existierenden Erscheinungen, literarischen Motiven, Figuren, Traditionen und Erzahlweisen. Harry Potter uberschreitet alle Grenzen: die der Sprache, des Marktes, der Adressatengruppe, der literarischen Genres und Traditionen. Die vielfaltige Sicht, die die Romanserie erforderlich macht, bedeutet zugleich eine Revision zumindest herkommlicher literaturwissenschaftlicher Arbeit.",
#     "industryIdentifiers": [
#      {
#       "type": "OTHER",
#       "identifier": "STANFORD:36105132592622"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 258,
#     "printType": "BOOK",
#     "categories": [
#      "Literary Criticism"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=bScqAQAAIAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=bScqAQAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=bScqAQAAIAAJ&dq=intitle:potter&hl=&cd=6&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=bScqAQAAIAAJ&dq=intitle:potter&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Kulturph%C3%A4nomen_Harry_Potter.html?hl=&id=bScqAQAAIAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=bScqAQAAIAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Above all, the texts themselves are examined, different readings are sounded out, and links are pursued to really understand the existing phenomena, literary motives, characters, traditions and narrative styles."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "fLlr5jyoAKkC",
#    "etag": "55xRhTRpLn8",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/fLlr5jyoAKkC",
#    "volumeInfo": {
#     "title": "Märchen-Motive in \"Harry Potter\"",
#     "authors": [
#      "Sonja Loidl"
#     ],
#     "publisher": "GRIN Verlag",
#     "publishedDate": "2007",
#     "description": "Studienarbeit aus dem Jahr 2006 im Fachbereich Deutsch - Gattungen, Note: 1, Universitat Wien (Germanistik), Veranstaltung: Zur Interpretation der Kinder- und Hausmarchen der Bruder Grimm, 32 Quellen im Literaturverzeichnis, Sprache: Deutsch, Anmerkungen: Eine Untersuchung uber die Moglichkeit der Zuordnung von Harry Potter zu den Marchen. Ausserdem werden ausgewahlte Motive (z.B.: Antiheld, Aschenputtel, Elfen, Riesen, dankbare Tote, ...) analysiert., Abstract: In dieser Abhandlung wird die Frage behandelt, ob beziehungsweise inwieweit die Harry-Potter-Reihe in die kinderliterarische Gattung Marchen\" eingeordnet werden kann. Zu diesem Zweck wird Rowlings Serie mit Definitionen der Gattung von Luthi verglichen. Ausserdem wird nachgewiesen werden, dass die Autorin zahlreiche Marchen-Motive in ihr Werk - mitunter in adaptierter Form - integriert hat. Einen auch nur annahernd vollstandigen Motiv-Index der Harry-Potter-Romane zu erstellen wurde den Rahmen dieser Untersuchung allerdings uberschreiten. Deshalb erfolgt eine Beschrankung auf neun Motive, denen ich drei hinzufuge, die meiner Ansicht nach reine Kreationen der Autorin sind. Fur Zitate und Potter-Begriffe\" werden die Orginialversionen der Bucher herangezogen werden, da ich aus Grunden, die an dieser Stelle nicht erlautert werden sollen, an der Qualitat der deutschen Ubersetzung zweifele. Gelegentlich werde ich aber deutsche Begriffe - sollten sie stark vom Original abweichen - in Klammer dazusetzen. Die Bezeichnung Romane\" fur die Harry-Potter-Bucher wird im Rahmen dieser Arbeit im Sinn einer langen, fiktiven Erzahlung in Prosa verwendet. Auch ein paar allgemeine Bemerkungen zum Phanomen, das das Werk darstellt, konnen naturlich nicht ausgespart bleiben. In die vorliegende Untersuchung sind die Bande eins bis inklusive sechs integriert.\"",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783638672597"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "363867259X"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 36,
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=fLlr5jyoAKkC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=fLlr5jyoAKkC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=fLlr5jyoAKkC&printsec=frontcover&dq=intitle:potter&hl=&cd=7&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=fLlr5jyoAKkC&dq=intitle:potter&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/M%C3%A4rchen_Motive_in_Harry_Potter.html?hl=&id=fLlr5jyoAKkC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=fLlr5jyoAKkC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Studienarbeit aus dem Jahr 2006 im Fachbereich Deutsch - Gattungen, Note: 1, Universität Wien (Germanistik), Veranstaltung: Zur Interpretation der Kinder- und Hausmärchen der Brüder Grimm, 32 Quellen im Literaturverzeichnis, Sprache: ..."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "7yD1uUdHdKUC",
#    "etag": "v2RQLb1QNTU",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/7yD1uUdHdKUC",
#    "volumeInfo": {
#     "title": "Harry Potter und der Halbblutprinz",
#     "authors": [
#      "J.K. Rowling"
#     ],
#     "publisher": "Pottermore Publishing",
#     "publishedDate": "2015-12-08",
#     "description": "Seit Voldemort, der gefährlichste schwarze Magier aller Zeiten, zurückgekehrt ist, herrschen Aufruhr und Gewalt in der magischen Welt. Als Harry Potter und seine Freunde Ron und Hermine zu ihrem sechsten Schuljahr nach Hogwarts kommen, gelten strengste Sicherheitsmaßnahmen in der Zauberschule. Dumbledore will seine Schützlinge vor dem Zugriff des Bösen bewahren. Um Harry zu wappnen, erforscht er mit ihm die Geschichte des Dunklen Lords. Ob auch Harrys Zaubertrankbuch, das früher einem „Halbblutzprinzen“ gehörte, ihm helfen kann?",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9781781100813"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "1781100810"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 656,
#     "printType": "BOOK",
#     "categories": [
#      "Juvenile Fiction"
#     ],
#     "averageRating": 3.0,
#     "ratingsCount": 13,
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "1.6.6.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=7yD1uUdHdKUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=7yD1uUdHdKUC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=7yD1uUdHdKUC&printsec=frontcover&dq=intitle:potter&hl=&cd=8&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=7yD1uUdHdKUC&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=7yD1uUdHdKUC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 10.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 10.0,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=7yD1uUdHdKUC&rdid=book-7yD1uUdHdKUC&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1.0E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 1.0E7,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Harry_Potter_und_der_Halbblutprinz-sample-epub.acsm?id=7yD1uUdHdKUC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Harry_Potter_und_der_Halbblutprinz-sample-pdf.acsm?id=7yD1uUdHdKUC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=7yD1uUdHdKUC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Seit Voldemort, der gefährlichste schwarze Magier aller Zeiten, zurückgekehrt ist, herrschen Aufruhr und Gewalt in der magischen Welt."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "hd8qDwAAQBAJ",
#    "etag": "e8kZ4KwMwE0",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/hd8qDwAAQBAJ",
#    "volumeInfo": {
#     "title": "Didaktische Analyse eines Jugendbuchklassikers \"Harry Potter und der Stein der Weisen\". Untersuchung auf die Eignung für den Literaturunterricht in der Schule",
#     "authors": [
#      "Julius Graf"
#     ],
#     "publisher": "GRIN Verlag",
#     "publishedDate": "2017-07-04",
#     "description": "Studienarbeit aus dem Jahr 2015 im Fachbereich Deutsch - Pädagogik, Didaktik, Sprachwissenschaft, Note: 2,3, Universität Regensburg, Sprache: Deutsch, Abstract: Nicht nur in der erschaffenen magischen Welt, in der Harry Potter einzig Überlebende des Todesfluchs und später der Bezwinger des Urbösen Lord Voldemorts ist, gilt er als sehr populär, sondern auch in der realen Welt, in der die Bücher auf Grund ihrer Beliebtheit und ihres Bekanntheitsgrades zu einem Phänomen werden. Es entwickelte sich eine regelrechte „Potter-Manie“, im Zuge derer die Bücher nicht nur begehrt waren bzw. sind, es herrschte sogar bei der Erscheinung eines neuen Bandes ein Ausnahmezustand der seinesgleichen suchte. Buchhandlungen öffneten ihre Türen um Mitternacht, wobei meterlange Schlangen wartender Fans zu beobachten waren, und auch die Deutsche Post lieferte den jeweils neu erscheinenden Band um 24 Uhr aus, damit das Herbeisehnen des neuesten magischen Abenteuers möglichst kurz ausfiel. Und all das begann aufgrund eines Mediums, dessen Rückgang man im Zeitalter des Internets eigentlich zu befürchten hatte. Es stellt sich deshalb zunächst ganz offenkundig die Frage nach den Gründen für derartige Begeisterungswellen, die von einem Buch ausgelöst wurden und natürlich auch in gewisser Weise, ob diese aus fachlicher Sicht gerechtfertigt sind. Des Weiteren soll im Folgenden untersucht werden, ob beim vorliegenden Werk - Harry Potter und der Stein der Weisen - eine Eignung für den Literaturunterricht vorliegt.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783668476455"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3668476454"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 17,
#     "printType": "BOOK",
#     "categories": [
#      "Foreign Language Study"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=hd8qDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=hd8qDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=hd8qDwAAQBAJ&printsec=frontcover&dq=intitle:potter&hl=&cd=9&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=hd8qDwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=hd8qDwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 14.99,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 10.19,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=hd8qDwAAQBAJ&rdid=book-hd8qDwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1.499E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 1.019E7,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Didaktische_Analyse_eines_Jugendbuchklas-sample-pdf.acsm?id=hd8qDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=hd8qDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Studienarbeit aus dem Jahr 2015 im Fachbereich Deutsch - Pädagogik, Didaktik, Sprachwissenschaft, Note: 2,3, Universität Regensburg, Sprache: Deutsch, Abstract: Nicht nur in der erschaffenen magischen Welt, in der Harry Potter einzig ..."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "Oe1s6jjPK6UC",
#    "etag": "h4Q/kGoe2gY",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/Oe1s6jjPK6UC",
#    "volumeInfo": {
#     "title": "Harry Potter - geretteter Retter im Kampf gegen dunkle Mächte?",
#     "subtitle": "religionspädagogischer Blick auf religiöse Implikationen, archaisch-mythologische Motive und supranaturale Elemente",
#     "authors": [
#      "Corinna Cornelius"
#     ],
#     "publisher": "LIT Verlag Münster",
#     "publishedDate": "2003",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "3825868303"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9783825868307"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 108,
#     "printType": "BOOK",
#     "categories": [
#      "Mythology in literature"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.0.3.0.preview.1",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=Oe1s6jjPK6UC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=Oe1s6jjPK6UC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=Oe1s6jjPK6UC&printsec=frontcover&dq=intitle:potter&hl=&cd=10&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=Oe1s6jjPK6UC&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=Oe1s6jjPK6UC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 10.68,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 7.26,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=Oe1s6jjPK6UC&rdid=book-Oe1s6jjPK6UC&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1.068E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 7260000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": true
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=Oe1s6jjPK6UC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    }
#   }
#  ]
# }
# {
#  "kind": "books#volumes",
#  "totalItems": 462,
#  "items": [
#   {
#    "kind": "books#volume",
#    "id": "dzTKDwAAQBAJ",
#    "etag": "5RVt7YG+/Tw",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/dzTKDwAAQBAJ",
#    "volumeInfo": {
#     "title": "Arthur Conan Doyle: Sherlock Holmes - Die Romane",
#     "authors": [
#      "Arthur Conan Doyle"
#     ],
#     "publisher": "Anaconda Verlag",
#     "publishedDate": "2014-04-17",
#     "description": "Sherlock Holmes ist der Inbegriff des scharfsinnigen Gentleman-Detektivs: Wenn er mit seinem Freund Dr. Watson ein wenig kombiniert, ist selbst der kniffligste Fall schon so gut wie gelöst. Die Welt des Sherlock Holmes ist eine Sammlung von Geschichten ganz unterschiedlicher Länge, an denen Arthur Conan Doyle zeitlebens geschrieben hat. Vier seiner Fälle wuchsen zu Romanform an, sie versammelt dieser zum Schmökern einladende Band: 'Eine Studie in Scharlachrot', 'Das Zeichen der Vier', 'Der Hund der Baskervilles' und 'Das Tal des Grauens'.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783730690604"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3730690604"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 640,
#     "printType": "BOOK",
#     "categories": [
#      "Fiction"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=dzTKDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=dzTKDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=dzTKDwAAQBAJ&printsec=frontcover&dq=inauthor:doyle&hl=&cd=1&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=dzTKDwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=dzTKDwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 9.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 6.12,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=dzTKDwAAQBAJ&rdid=book-dzTKDwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 9000000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 6120000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Arthur_Conan_Doyle_Sherlock_Holmes_Die_R-sample-epub.acsm?id=dzTKDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Arthur_Conan_Doyle_Sherlock_Holmes_Die_R-sample-pdf.acsm?id=dzTKDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=dzTKDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Die Welt des Sherlock Holmes ist eine Sammlung von Geschichten ganz unterschiedlicher Länge, an denen Arthur Conan Doyle zeitlebens geschrieben hat."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "LqW_DwAAQBAJ",
#    "etag": "MNk3R51Rcbc",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/LqW_DwAAQBAJ",
#    "volumeInfo": {
#     "title": "Das letzte Problem",
#     "authors": [
#      "Sir Arthur Conan Doyle"
#     ],
#     "publisher": "Lindhardt og Ringhof",
#     "publishedDate": "2019-12-02",
#     "description": "Schafft es Sherlock Holmes, seinem Erzfeind Moriarty doch noch zu entkommen? Nachdem Holmes nach monatelanger Recherche das hochkriminelle Genie Moriarty und dessen Agenten beinahe auf die Anklagebank führen kann, entkommt Holmes nur knapp drei Mordanschlägen. Er und Dr. Watson beschließen daraufhin zu fliehen. Nachdem sie auf Umwegen in der Schweiz ankommen, wird es allerdings ernst für Holmes... Arthur Conan Doyle (1859-1930) war ein britischer Arzt und Schriftsteller. Aufgewachsen in Schottland, studierte er Medizin in Edinburgh und lebte später in England. 1887 veröffentlichte er seine erste Detektivgeschichte über Sherlock Holmes und dessen Freund Dr. Watson und wurde damit weltberühmt. Die Erzählungen sind bis heute ein Klassiker der Kriminalliteratur. Insgesamt gibt es vier Sherlock-Holmes-Romane und 56 Kurzgeschichten.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9788726372205"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "8726372207"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": false
#     },
#     "pageCount": 42,
#     "printType": "BOOK",
#     "categories": [
#      "Fiction"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.2.2.0.preview.2",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=LqW_DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=LqW_DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=LqW_DwAAQBAJ&printsec=frontcover&dq=inauthor:doyle&hl=&cd=2&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=LqW_DwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=LqW_DwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 2.22,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 2.22,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=LqW_DwAAQBAJ&rdid=book-LqW_DwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 2220000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 2220000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Das_letzte_Problem-sample-epub.acsm?id=LqW_DwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=LqW_DwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Er und Dr. Watson beschließen daraufhin zu fliehen. Nachdem sie auf Umwegen in der Schweiz ankommen, wird es allerdings ernst für Holmes... Arthur Conan Doyle (1859-1930) war ein britischer Arzt und Schriftsteller."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "Zm0bAgAAQBAJ",
#    "etag": "iUr65kV9JeM",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/Zm0bAgAAQBAJ",
#    "volumeInfo": {
#     "title": "Die Werke von Arthur Conan Doyle - Komplette Sherlock Holmes (Illustrierte)",
#     "authors": [
#      "Arthur Conan Doyle"
#     ],
#     "publisher": "Delphi Classics",
#     "publishedDate": "2013-11-17",
#     "description": "Sherlock Holmes - Detektiv und eine der berühmtesten und meist geliebten Figuren der englischen Romanliteratur - wurde von dem Autor und Arzt Sir Arthur Conan Doyle erschaffen. Jetzt genießen Sie die Werke von Conan Doyle auf Ihrem E-Reader. Diese enorme Sammlung umfasst auch spezielle Bonustexte. (15MB Version 1) Merkmale: * die vollständige Sherlock-Holmes-Romane, mit Inhaltsverzeichnissen * eine Einführung in die berühmte Detektivliteratur * kurze Einführungen in die Romane und anderen Texte * die Sherlock-Holmes-Sammlungen von Kurzgeschichten, mit Inhaltsverzeichnissen * zahlreiche Bilder mit Bezug zu Conan Doyle, seinem Leben und seinen Werken * beinhaltet vier weitere berühmte Romane INHALT: Sherlock Holmes: eine Einleitung Die Sherlock-Holmes-Romane SPÄTE RACHE DAS ZEICHEN DER VIER DER HUND DER BASKERVILLES DAS TAL DES GRAUENS Die Sherlock-Holmes-Sammlungen von Kurzgeschichten ALS SHERLOCK HOLMES AUS LHASSA KAM DAS GETUPFTE BAND UND ANDERE DETEKTIVGESCHICHTEN DER BUND DER ROTHAARIGEN UND ANDERE DETEKTIVGESCHICHTEN DIE TANZENDEN MÄNNCHEN DER STERBENDE SHERLOCK HOLMES UND ANDERE DETEKTIVGESCHICHTEN FÜNF APFELSINENKERNE UND ANDERE DETEKTIVGESCHICHTEN Die Sherlock-Holmes-Erzählungen LISTE DER GESCHICHTEN IN ALPHABETISCHER REIHENFOLGE Weitere Romane MICAH CLARKE THE REFUGEES UNCLE BERNAC THE MYSTERY OF CLOOMBER",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9781909496156"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "1909496154"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 3491,
#     "printType": "BOOK",
#     "categories": [
#      "Fiction"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=Zm0bAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=Zm0bAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=Zm0bAgAAQBAJ&printsec=frontcover&dq=inauthor:doyle&hl=&cd=3&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=Zm0bAgAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=Zm0bAgAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 2.93,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 2.43,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=Zm0bAgAAQBAJ&rdid=book-Zm0bAgAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 2930000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 2430000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Die_Werke_von_Arthur_Conan_Doyle_Komplet-sample-epub.acsm?id=Zm0bAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Die_Werke_von_Arthur_Conan_Doyle_Komplet-sample-pdf.acsm?id=Zm0bAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=Zm0bAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Sherlock Holmes - Detektiv und eine der berühmtesten und meist geliebten Figuren der englischen Romanliteratur - wurde von dem Autor und Arzt Sir Arthur Conan Doyle erschaffen."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "CaW_DwAAQBAJ",
#    "etag": "/xxUkgGY9hY",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/CaW_DwAAQBAJ",
#    "volumeInfo": {
#     "title": "Das gelbe Gesicht",
#     "authors": [
#      "Sir Arthur Conan Doyle"
#     ],
# ...
#       "identifier": "3668061629"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 19,
#     "printType": "BOOK",
#     "categories": [
#      "Literary Collections"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "0.3.2.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=0lM6CwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=0lM6CwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=0lM6CwAAQBAJ&printsec=frontcover&dq=intitle:potter&hl=&cd=37&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=0lM6CwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=0lM6CwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 15.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 10.2,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=0lM6CwAAQBAJ&rdid=book-0lM6CwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1.5E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 1.02E7,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Die_Harry_Potter_B%C3%BCcher_von_Joanne_K_Ro-sample-epub.acsm?id=0lM6CwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Die_Harry_Potter_B%C3%BCcher_von_Joanne_K_Ro-sample-pdf.acsm?id=0lM6CwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=0lM6CwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Studienarbeit aus dem Jahr 2015 im Fachbereich Literaturwissenschaft - Moderne Literatur, Note: 1,0, Universität Bielefeld (Fakultät für Linguistik und Literaturwissenschaft), Veranstaltung: Phantastische Kinderliteratur, Sprache: ..."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "c_KYSDoCYQ4C",
#    "etag": "zIVS16ZU/G0",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/c_KYSDoCYQ4C",
#    "volumeInfo": {
#     "title": "The Magic of Harry Potter",
#     "authors": [
#      "Daniel Mitchell"
#     ],
#     "publisher": "Lulu.com",
#     "publishedDate": "2007-12-01",
#     "description": "The Harry Potter books by J. K. Rowling have been phenomenal bestsellers winning fans world wide. These essays look at the magic, literary devices and moral themes in the Harry Potter series. In addition, the controversy between Christians over the moral themes is discussed.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9780615172828"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "0615172822"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 108,
#     "printType": "BOOK",
#     "categories": [
#      "Fiction"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "0.1.2.0.preview.3",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=c_KYSDoCYQ4C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=c_KYSDoCYQ4C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=c_KYSDoCYQ4C&printsec=frontcover&dq=intitle:potter&hl=&cd=38&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=c_KYSDoCYQ4C&dq=intitle:potter&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/The_Magic_of_Harry_Potter.html?hl=&id=c_KYSDoCYQ4C"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/The_Magic_of_Harry_Potter-sample-epub.acsm?id=c_KYSDoCYQ4C&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=c_KYSDoCYQ4C&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "The Harry Potter books by J. K. Rowling have been phenomenal bestsellers winning fans world wide. These essays look at the magic, literary devices and moral themes in the Harry Potter series."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "XL7GDgAAQBAJ",
#    "etag": "h5xxXUmiHs4",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/XL7GDgAAQBAJ",
#    "volumeInfo": {
#     "title": "Das inoffizielle Harry-Potter-Buch der Verwünschungen",
#     "subtitle": "101 Möglichkeiten, dich gegen fiese Slytherins zu wehren",
#     "authors": [
#      "Birdy Jones",
#      "Laura J. Moss"
#     ],
#     "publisher": "Riva Verlag",
#     "publishedDate": "2017-09-11",
#     "description": "Fieslinge, macht euch auf etwas gefasst – ihr sollt nie wieder unbescholten davonkommen! Nicht nur an Muggel-Schulen, sondern auch in Hogwarts treiben Fieslinge ihr Unwesen. Slytherin bringt die Übelsten dieser Sorte hervor – vor allem den schrecklichen Du-weißt-schon-wen –, doch auch in den anderen Häusern sind sie zu finden. In Ravenclaw stößt man immer wieder auf den feindseligen Typus des Klugscheißers, und auch ein paar Gryffindors nutzen ihren Mumm für gemeine Zwecke. Selbst Hufflepuff bringt gelegentlich eine nicht ganz so gut gesinnte Hexe hervor, gegen die man sich verteidigen muss. In diesem Buch findest du die 101 schlagfertigsten Verwünschungen aus der magischen Harry-Potter-Welt, die sich kinderleicht in der Muggel-Welt anwenden lassen. Wenn dich das nächste Mal ein brutaler Typ wie Malfoy nicht in Frieden lässt, setz dich mit einem \"Du bist schlimmer als alle sieben Horkruxe zusammen\" zur Wehr. Oder wappne dich mit einem \"Du bist ungefähr so schlau, wie Dudley schlank ist\", wenn dir ein Besserwisser das Leben schwer macht. Jetzt bist du an der Reihe, deine Widersacher sprachlos zurückzulassen.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783959716840"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3959716842"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 96,
#     "printType": "BOOK",
#     "categories": [
#      "Juvenile Nonfiction"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "1.7.7.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=XL7GDgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=XL7GDgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=XL7GDgAAQBAJ&printsec=frontcover&dq=intitle:potter&hl=&cd=39&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=XL7GDgAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=XL7GDgAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 11.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 7.48,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=XL7GDgAAQBAJ&rdid=book-XL7GDgAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1.1E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 7480000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Das_inoffizielle_Harry_Potter_Buch_der_V-sample-epub.acsm?id=XL7GDgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Das_inoffizielle_Harry_Potter_Buch_der_V-sample-pdf.acsm?id=XL7GDgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=XL7GDgAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Fieslinge, macht euch auf etwas gefasst – ihr sollt nie wieder unbescholten davonkommen!"
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "6Uh-R-PMObEC",
#    "etag": "+HgHOF2e8YA",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/6Uh-R-PMObEC",
#    "volumeInfo": {
#     "title": "Warum ist „Harry Potter“ populär? Wie J.K. Rowling lesefaule Kinder erreicht",
#     "subtitle": "Mit Ideen für eine Unterrichtsreihe",
#     "authors": [
#      "Melanie Janet Göbel",
#      "Silke Hoffmann"
#     ],
#     "publisher": "GRIN Verlag",
#     "publishedDate": "2005-07-20",
#     "description": "Studienarbeit aus dem Jahr 2003 im Fachbereich Englisch - Pädagogik, Didaktik, Sprachwissenschaft, Note: 2,3, Heinrich-Heine-Universität Düsseldorf (Anglistisches Institut), Veranstaltung: Popular Literatur, 7 Quellen im Literaturverzeichnis, Sprache: Deutsch, Abstract: He`ll be famous – a legend – [...] there will be books written about Harry – every child in our world will know his name.1 Dass dies auch einmal auf die reale Mugglewelt zutreffen würde, hätte wohl auch Professor McGonagall nie gedacht, als sie diese Aussage über Harry Potter`s Popularität in der fiktiven Zaubererwelt zu Beginn des ersten Bandes traf. Die bisher erschienenen vier Bände der Autorin Joanne K. Rowling rund um den Zauberer Harry Potter kann man zweifelsohne als Phänomen bezeichnen, als etwas, das ungewöhnlich und auffällig erscheint.2 Doch in diesem Fall sind nicht etwa die Inhalte ungewöhnlich und auffällig, denn es handelt sich hierbei eigentlich um ein relativ „normales“ Kinderbuch, das man in das literarische Feld der fantastischen Kinder- und Jugendliteratur einordnen kann. 3 Als Phänomen ist in diesem Fall vielmehr der weltweit gigantische Erfolg dieser Buchserie zu nennen, denn es gibt wohl kaum ein anderes Kinderbuch, das in mehr als 40 Sprachen übersetzt wurde4, und kaum ein Kind im lesefähigen Alter, das die Bücher nicht „verschlungen“ und sich nicht vom „Potter- Fieber“ hat anstecken lassen. Die Journalistin und Literaturwissenschaftlerin Susanne Gaschke schrieb dazu in der Wochenzeitung Die Zeit: Keine andere literarische Figur hat Kinder auf der ganzen Welt in den vergangenen Jahren mehr beschäftigt als Harry Potter.5 Laut einer Umfrage der Süddeutschen Zeitung ist Harry Potter in Großbritannien tatsächlich bekannter als jede andere literarische Figur, einschließlich Sherlock Holmes, James Bond und Miss Marple.6 -------- 1 Rowling, J. K.: Harry Potter and the Philosopher`s Stone. London, 1997: S. 20 2 Vgl.: Knobloch, Jörg: Die Zauberwelt der J.K. Rowling: Hintergründe & Facts zu “Harry Potter“. Mühlheim an der Ruhr, 2000: S. 48 3 Vgl.: Gerhard Haas: „Harry Potter“ im Kontext der fantastischen Kinder- und Jugendliteratur in Knobloch, Jörg (Hrsg.): “Harry Potter“ in der Schule: Didaktische Annäherung an ein Phänomen. Mühlheim an der Ruhr, 2001: S. 15ff. 4 Vgl.: Knobloch, Jörg, Die Zauberwelt der J.K. Rowling: Hintergründe & Facts zu “Harry Potter“. Mühlheim an der Ruhr, 2000: S. 49 5 Bürvenich, Paul: Der Zauber des Harry Potter, Frankfurt am Main. 2001: S. 11 6 Vgl.: Odendahl, Ursula: Introduction to Children`s Literature. Internetseite: http://www.hausarbeiten.de, aufgerufen am15.03.2003",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783638400718"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3638400719"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 42,
#     "printType": "BOOK",
#     "categories": [
#      "Foreign Language Study"
#     ],
#     "averageRating": 1.0,
#     "ratingsCount": 4,
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "2.7.2.0.preview.1",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=6Uh-R-PMObEC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=6Uh-R-PMObEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=6Uh-R-PMObEC&printsec=frontcover&dq=intitle:potter&hl=&cd=40&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=6Uh-R-PMObEC&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=6Uh-R-PMObEC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 14.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 9.52,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=6Uh-R-PMObEC&rdid=book-6Uh-R-PMObEC&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1.4E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 9520000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Warum_ist_Harry_Potter_popul%C3%A4r_Wie_J_K-sample-pdf.acsm?id=6Uh-R-PMObEC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=6Uh-R-PMObEC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Studienarbeit aus dem Jahr 2003 im Fachbereich Englisch - Pädagogik, Didaktik, Sprachwissenschaft, Note: 2,3, Heinrich-Heine-Universität Düsseldorf (Anglistisches Institut), Veranstaltung: Popular Literatur, 7 Quellen im ..."
#    }
#   }
#  ]
# }

# %% [markdown]
# 1G. Define a function that sends a request to the google books API with the URL parameters as inputs to the function. Try to incorporate as many as the variables as possible and output a URL according to the settings you want to have. Don't forget to write a docstring explaning how the function works. Docstrings are explanations to functions, describing the input, output, and purpose of the function. If you haven't used them before, you can find more examples for example at: https://www.geeksforgeeks.org/python-docstrings/

# %%
def request_books_api(keyword:str, value="", dic = {}):
    '''
    This function performs requests to the google book API.
    
    Parameters:
        keyword: keywords that you can specify in the search term to search for particular fields
        value: value for the particular keywords
        dic: dictionary that contains other keyword-value pairs to continue the query (e.g. {"startIndex":10})
        
    Returns:
        The results of the API request, so a dictionary containing key-value pair information about each result
    '''
    # Format url with the given parameters
    if value != "":
        
        # Use dictionary key value pairs if given
        if dic != {}:  
            url = "https://www.googleapis.com/books/v1/volumes?q={}:{}&{}={}".format(keyword, value, list(dic.keys())[0], list(dic.values())[0])
        else:
            url = "https://www.googleapis.com/books/v1/volumes?q={}:{}".format(keyword, value)
    
    # If no search value is given, only use the keyword
    else:
        url = "https://www.googleapis.com/books/v1/volumes?q={}".format(keyword)
        
    # Send request with the formatted url
    return requests.get(url).text


# Example query:
print(request_books_api("inauthor", "freud", {"maxResults":40}))
# Out:
# {
#  "kind": "books#volumes",
#  "totalItems": 494,
#  "items": [
#   {
#    "kind": "books#volume",
#    "id": "RAoMBAAAQBAJ",
#    "etag": "aj9RjFDPtDg",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/RAoMBAAAQBAJ",
#    "volumeInfo": {
#     "title": "Anna Freud",
#     "authors": [
#      "Anna Freud"
#     ],
#     "publisher": "Böhlau Verlag Wien",
#     "publishedDate": "2014",
#     "description": "Die Herausgeberin Brigitte Spreitzer macht die literarischen Texte von Sigmund Freuds jüngster Tochter Anna Freud zum ersten Mal vollständig zugänglich und liest sie in der Einführung zur Edition als paradigmatische Dokumente der Aus-einandersetzung einer jungen Frau aus dem assimilierten jüdischen Bürgertum mit den sozi¬alhistorischen und kulturellen Bedingungen im Wien der Jahrhundertwende. Damit werden sie als Teil eines historischen Prozesses begreifbar gemacht, der durch das Ringen von Frauen um Zutritt zu Kultur, Bildung und Wissen gekennzeichnet ist. So werden Verbindungslinien von Psychoanalyse, Konstruktionen von Weiblichkeit und individuellem Frau¬enleben nachvollziehbar.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783205794974"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3205794974"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 363,
#     "printType": "BOOK",
#     "categories": [
#      "German literature"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "0.1.0.0.preview.1",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=RAoMBAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=RAoMBAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=RAoMBAAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=1&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=RAoMBAAAQBAJ&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Anna_Freud.html?hl=&id=RAoMBAAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=RAoMBAAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Die Psychoanalytikerin Anna Freud ist nicht nur Insidern ein Begriff."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "ELVACgAAQBAJ",
#    "etag": "L/KK5oWD9j0",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/ELVACgAAQBAJ",
#    "volumeInfo": {
#     "title": "War and Children",
#     "authors": [
#      "Anna Freud"
#     ],
#     "publisher": "Lulu Press, Inc",
#     "publishedDate": "2015-07-16",
#     "description": "This book looks at the record of children in modern war told honestly and completely, by two of the world's outstanding child psychologists, Anna Freud and Dorothy Burlingham. The work focuses on how war affects psychological development in children; the need for personal attachment, for emotional stability, and for permanency of educational influence.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9781329380271"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "1329380274"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "printType": "BOOK",
#     "categories": [
#      "Science"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=ELVACgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=ELVACgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=ELVACgAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=2&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=ELVACgAAQBAJ&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/War_and_Children.html?hl=&id=ELVACgAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/War_and_Children-sample-epub.acsm?id=ELVACgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/War_and_Children-sample-pdf.acsm?id=ELVACgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=ELVACgAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "This book looks at the record of children in modern war told honestly and completely, by two of the world&#39;s outstanding child psychologists, Anna Freud and Dorothy Burlingham."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "KWJS6TnRVrEC",
#    "etag": "yfHRZNRvRnw",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/KWJS6TnRVrEC",
#    "volumeInfo": {
#     "title": "JENSEITS DES LUSTPRINZIPS ",
#     "authors": [
#      "SIGM. FREUD"
#     ],
#     "publishedDate": "1921",
#     "industryIdentifiers": [
#      {
#       "type": "OTHER",
#       "identifier": "UOMDLP:acu9165:0001.001"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.1.0.0.preview.0",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=KWJS6TnRVrEC&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=KWJS6TnRVrEC&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=KWJS6TnRVrEC&dq=inauthor:freud&hl=&cd=3&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=KWJS6TnRVrEC&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/JENSEITS_DES_LUSTPRINZIPS.html?hl=&id=KWJS6TnRVrEC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": true
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=KWJS6TnRVrEC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "0b8m3UKieUcC",
#    "etag": "djzOE5oxxSI",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/0b8m3UKieUcC",
#    "volumeInfo": {
#     "title": "Three Case Histories",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Simon and Schuster",
#     "publishedDate": "2008-06-30",
#     "description": "These histories reveal not only the working of the unconscious in paranoid and neurotic cases, but also the agility of Freud's own mind and his method for treating the disorders. Notes upon a case of obessional neurosis (1909) Pscyhoanalytic notes upon an autobiographical account of a case of paranoia (dementia paranoides) (1911) From the history of an infantile neurosis (1918)",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "1439108110"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9781439108116"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": false
#     },
#     "pageCount": 282,
#     "printType": "BOOK",
#     "categories": [
#      "Psychology"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "0.6.7.0.preview.2",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=0b8m3UKieUcC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=0b8m3UKieUcC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=0b8m3UKieUcC&printsec=frontcover&dq=inauthor:freud&hl=&cd=4&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=0b8m3UKieUcC&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Three_Case_Histories.html?hl=&id=0b8m3UKieUcC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED_FOR_ACCESSIBILITY",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Three_Case_Histories-sample-epub.acsm?id=0b8m3UKieUcC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=0b8m3UKieUcC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "These histories reveal not only the working of the unconscious in paranoid and neurotic cases, but also the agility of Freud&#39;s own mind and his method for treating the disorders."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "T4IrAAAAYAAJ",
#    "etag": "XKLrbSf5V3Q",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/T4IrAAAAYAAJ",
#    "volumeInfo": {
#     "title": "1945-1956",
#     "subtitle": "Bd 4 ; 1945-1956 : Indikationsstellung in der Kinderanalyse und andere Schriften",
#     "authors": [
#      "Anna Freud"
#     ],
#     "publishedDate": "1987",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "3596268141"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9783596268146"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 6,
#     "printType": "BOOK",
#     "categories": [
#      "Child analysis"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=T4IrAAAAYAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=T4IrAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=T4IrAAAAYAAJ&dq=inauthor:freud&hl=&cd=5&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=T4IrAAAAYAAJ&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/1945_1956.html?hl=&id=T4IrAAAAYAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=T4IrAAAAYAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "OjfKDwAAQBAJ",
#    "etag": "CliMRPf+o6E",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/OjfKDwAAQBAJ",
#    "volumeInfo": {
#     "title": "Abriss der Psychoanalyse",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Anaconda Verlag",
#     "publishedDate": "2016-02-07",
#     "description": "Freuds Lebenswerk kompakt und verständlich: Der seelische Apparat und die Funktion der einzelnen Instanzen, Triebleben und Sexualentwicklung, die Bedeutung der Träume, das Un- und das Vorbewusste, der Ödipus-Komplex und weitere zentrale Elemente seiner Lehre kommen in diesem 'Abriss' zur Sprache.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783730691366"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3730691368"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 96,
#     "printType": "BOOK",
#     "categories": [
#      "Psychology"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=OjfKDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=OjfKDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=OjfKDwAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=6&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=OjfKDwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=OjfKDwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 2.5,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 2.5,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=OjfKDwAAQBAJ&rdid=book-OjfKDwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 2500000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 2500000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Abriss_der_Psychoanalyse-sample-epub.acsm?id=OjfKDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Abriss_der_Psychoanalyse-sample-pdf.acsm?id=OjfKDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=OjfKDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Freuds Lebenswerk kompakt und verständlich: Der seelische Apparat und die Funktion der einzelnen Instanzen, Triebleben und Sexualentwicklung, die Bedeutung der Träume, das Un- und das Vorbewusste, der Ödipus-Komplex und weitere zentrale ..."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "G3x-CgAAQBAJ",
#    "etag": "lJsiGf6O4O0",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/G3x-CgAAQBAJ",
#    "volumeInfo": {
#     "title": "Jokes and their Relation to the Unconscious",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Read Books Ltd",
#     "publishedDate": "2014-11-11",
#     "description": "This early work by Sigmund Freud was originally published in 1905 and we are now republishing it with a brand new introductory biography. 'Jokes and their Relation to the Unconscious' is a psychological work on the effects on the mind of jokes. Sigismund Schlomo Freud was born on 6th May 1856, in the Moravian town of Příbor, now part of the Czech Republic. He studied a variety of subjects, including philosophy, physiology, and zoology, graduating with an MD in 1881. Freud made a huge and lasting contribution to the field of psychology with many of his methods still being used in modern psychoanalysis. He inspired much discussion on the wealth of theories he produced and the reactions to his works began a century of great psychological investigation.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9781473396210"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "1473396212"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 355,
#     "printType": "BOOK",
#     "categories": [
#      "Psychology"
#     ],
#     "averageRating": 5.0,
#     "ratingsCount": 1,
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "1.2.3.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=G3x-CgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=G3x-CgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=G3x-CgAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=7&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=G3x-CgAAQBAJ&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Jokes_and_their_Relation_to_the_Unconsci.html?hl=&id=G3x-CgAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Jokes_and_their_Relation_to_the_Unconsci-sample-epub.acsm?id=G3x-CgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Jokes_and_their_Relation_to_the_Unconsci-sample-pdf.acsm?id=G3x-CgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=G3x-CgAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "This early work by Sigmund Freud was originally published in 1905 and we are now republishing it with a brand new introductory biography."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "0AJkDwAAQBAJ",
#    "etag": "hqgoEvOX80M",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/0AJkDwAAQBAJ",
#    "volumeInfo": {
#     "title": "Sigmund Freud: Der Witz und seine Beziehung zum Unbewußten",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "e-artnow",
#     "publishedDate": "2017-11-15",
#     "description": "Der Witz und seine Beziehung zum Unbewußten ist der Titel einer Studie, in welcher der Psychoanalytiker Sigmund Freud 1905 die Funktionsweise und Bedeutung des Witzes untersuchte. Freud präsentiert frühere Untersuchungen, um dann an konkreten Beispielen spezifische Merkmale des Witzes mit seiner Theorie der Psychodynamik zu verbinden. Die Studie gilt als Schlüsselwerk der Psychoanalyse und Witzforschung. Sigmund Freud (1856-1939) war ein österreichischer Neurologe, Tiefenpsychologe, Kulturtheoretiker und Religionskritiker. Er war der Begründer der Psychoanalyse und gilt als einer der einflussreichsten Denker des 20. Jahrhunderts. Seine Theorien und Methoden werden bis heute diskutiert und angewendet.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9788027227457"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "8027227453"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 181,
#     "printType": "BOOK",
#     "categories": [
#      "Psychology"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.2.2.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=0AJkDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=0AJkDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=0AJkDwAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=8&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=0AJkDwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=0AJkDwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 0.53,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 0.53,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=0AJkDwAAQBAJ&rdid=book-0AJkDwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 530000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 530000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true
#     },
#     "pdf": {
#      "isAvailable": true
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=0AJkDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Der Witz und seine Beziehung zum Unbewußten ist der Titel einer Studie, in welcher der Psychoanalytiker Sigmund Freud 1905 die Funktionsweise und Bedeutung des Witzes untersuchte."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "OLuciK2wZXYC",
#    "etag": "j9iwLc69UsE",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/OLuciK2wZXYC",
#    "volumeInfo": {
#     "title": "Totem und Tabu",
#     "authors": [
#      "Herman Westerink",
#      "Sigmund Freud"
#     ],
#     "publisher": "V&R unipress GmbH",
#     "publishedDate": "2012-11",
#     "description": "English summary: Almost a century after its first publication, \"Totem and Tabu,\" one of Freud's major works on culture and religion, has been re-printed and commented in detail. The new edition not only outlines the contemporary context of the work, its reception and Viennese reactions to it. It also addresses the continued relevance of this important, controversial work: It considers the topic of guilt in various religions as historical constructions, thereby rejecting the tendency to derive the complexity of religions from hereditary and natural mental processes. The development of religion is not interpreted as a progressive, evolutionary and target-oriented process; religion is more like a stage for human dramas and spiritual conflicts, i.e. it is ultimately understood as the expression and regulation of instinct in relation to objects. German description: Totem und Tabu, eines von Freuds Hauptwerken uber Kultur und Religion, wird jetzt, fast 100 Jahre nach der Erstpublikation, neu herausgegeben und ausfuhrlich kommentiert. Nicht nur der zeitgenossische Kontext des Werks, seine Rezeption und Wiener Reaktionen darauf werden skizziert. Auch wird ausfuhrlich auf die bleibende Aktualitat dieses wichtigen und kontroversiellen Werkes eingegangen: Es betrachtet die Schuldproblematik in den verschiedenen Religionen als historische Konstruktionen und Wanderungen und will die Komplexitat der Religionen nicht von angeborenen und naturlichen psychischen Prozessen ableiten. Religionsentwicklung wird nicht als progressiv-evolutionarer und zielorientierter Prozess gedeutet; die Religion erscheint als Buhne menschlicher Dramen und seelischer Konflikte, d.h. sie wird letztlich als Ausdruck und Ordnung des Trieblebens in Beziehung zu Objekten verstanden.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783847100218"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3847100211"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 213,
#     "printType": "BOOK",
#     "categories": [
#      "Philosophy"
#     ],
#     "maturityRating": "MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=OLuciK2wZXYC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=OLuciK2wZXYC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=OLuciK2wZXYC&printsec=frontcover&dq=inauthor:freud&hl=&cd=9&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=OLuciK2wZXYC&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Totem_und_Tabu.html?hl=&id=OLuciK2wZXYC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=OLuciK2wZXYC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "It also addresses the continued relevance of this important, controversial work: It considers the topic of guilt in various religions as historical constructions, thereby rejecting the tendency to derive the complexity of religions from ..."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "8f3-uKZOHekC",
#    "etag": "oGho39qAJT8",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/8f3-uKZOHekC",
#    "volumeInfo": {
#     "title": "The Uncanny",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Penguin UK",
#     "publishedDate": "2003-07-31",
#     "description": "An extraordinary collection of thematically linked essays, including THE UNCANNY, SCREEN MEMORIES and FAMILY ROMANCES. Leonardo da Vinci fascinated Freud primarily because he was keen to know why his personality was so incomprehensible to his contemporaries. In this probing biographical essay he deconstructs both da Vinci's character and the nature of his genius. As ever, many of his exploratory avenues lead to the subject's sexuality - why did da Vinci depict the naked human body the way hedid? What of his tendency to surround himself with handsome young boys that he took on as his pupils? Intriguing, thought-provoking and often contentious, this volume contains some of Freud's best writing.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9780141930503"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "0141930500"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": false
#     },
#     "pageCount": 240,
#     "printType": "BOOK",
#     "categories": [
#      "Literary Collections"
#     ],
#     "averageRating": 4.5,
#     "ratingsCount": 2,
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "1.7.7.0.preview.2",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=8f3-uKZOHekC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=8f3-uKZOHekC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=8f3-uKZOHekC&printsec=frontcover&dq=inauthor:freud&hl=&cd=10&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=8f3-uKZOHekC&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=8f3-uKZOHekC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 10.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 10.0,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=8f3-uKZOHekC&rdid=book-8f3-uKZOHekC&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1.0E7,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 1.0E7,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED_FOR_ACCESSIBILITY",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/The_Uncanny-sample-epub.acsm?id=8f3-uKZOHekC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=8f3-uKZOHekC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "What of his tendency to surround himself with handsome young boys that he took on as his pupils? Intriguing, thought-provoking and often contentious, this volume contains some of Freud&#39;s best writing."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "l0pzCwAAQBAJ",
#    "etag": "slznvB7IdRk",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/l0pzCwAAQBAJ",
#    "volumeInfo": {
#     "title": "Über die weibliche Sexualität",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "BoD – Books on Demand",
#     "publishedDate": "2016-08-30",
#     "description": "Sigmund Freud (1856-1939) war ein österreichischer Neurologe, Tiefenpsychologe, Kulturtheoretiker und Religionskritiker. Er wurde weltweit als Begründer der Psychoanalyse bekannt. Freud gilt als einer der einflussreichsten Denker des 20. Jahrhunderts. Seine Theorien und Methoden werden bis heute angewendet und diskutiert.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783739224404"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3739224401"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 26,
#     "printType": "BOOK",
#     "categories": [
#      "Psychology"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "1.2.2.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=l0pzCwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=l0pzCwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=l0pzCwAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=11&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=l0pzCwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=l0pzCwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 3.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 2.49,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=l0pzCwAAQBAJ&rdid=book-l0pzCwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 3000000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 2490000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true
#     },
#     "pdf": {
#      "isAvailable": true
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=l0pzCwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Sigmund Freud (1856-1939) war ein österreichischer Neurologe, Tiefenpsychologe, Kulturtheoretiker und Religionskritiker. Er wurde weltweit als Begründer der Psychoanalyse bekannt. Freud gilt als einer der einflussreichsten Denker des 20."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "-pB1UoFnjZcC",
#    "etag": "09LuOxJq2iU",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/-pB1UoFnjZcC",
#    "volumeInfo": {
#     "title": "The Interpretation of Dreams",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Wordsworth Editions",
#     "publishedDate": "1997",
#     "description": "A translation of Sigmund Freud's \"The Interpretation of Dreams\" that is based on the original text published in November 1899.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "1853264849"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9781853264849"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 452,
#     "printType": "BOOK",
#     "categories": [
#      "Fiction"
#     ],
#     "averageRating": 3.5,
#     "ratingsCount": 388,
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.1.4.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=-pB1UoFnjZcC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=-pB1UoFnjZcC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=-pB1UoFnjZcC&printsec=frontcover&dq=inauthor:freud&hl=&cd=12&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=-pB1UoFnjZcC&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/The_Interpretation_of_Dreams.html?hl=&id=-pB1UoFnjZcC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/The_Interpretation_of_Dreams-sample-epub.acsm?id=-pB1UoFnjZcC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=-pB1UoFnjZcC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "A translation of Sigmund Freud&#39;s &quot;The Interpretation of Dreams&quot; that is based on the original text published in November 1899."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "CsrODwAAQBAJ",
#    "etag": "st/Bh+sQRBI",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/CsrODwAAQBAJ",
#    "volumeInfo": {
#     "title": "Das Tabu und die Ambivalenz der Gefühlsregungen",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Good Press",
#     "publishedDate": "2020-02-04",
#     "description": "\"Das Tabu und die Ambivalenz der Gefühlsregungen\" von Sigmund Freud. Veröffentlicht von Good Press. Good Press ist Herausgeber einer breiten Büchervielfalt mit Titeln jeden Genres. Von bekannten Klassikern, Belletristik und Sachbüchern bis hin zu in Vergessenheit geratenen bzw. noch unentdeckten Werken der grenzüberschreitenden Literatur, bringen wir Bücher heraus, die man gelesen haben muss. Jede eBook-Ausgabe von Good Press wurde sorgfältig bearbeitet und formatiert, um das Leseerlebnis für alle eReader und Geräte zu verbessern. Unser Ziel ist es, benutzerfreundliche eBooks auf den Markt zu bringen, die für jeden in hochwertigem digitalem Format zugänglich sind.",
#     "industryIdentifiers": [
#      {
#       "type": "OTHER",
#       "identifier": "EAN:4064066116729"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 166,
#     "printType": "BOOK",
#     "categories": [
#      "Fiction"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.1.1.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=CsrODwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=CsrODwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=CsrODwAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=13&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=CsrODwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=CsrODwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 1.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 1.0,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=CsrODwAAQBAJ&rdid=book-CsrODwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1000000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 1000000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Das_Tabu_und_die_Ambivalenz_der_Gef%C3%BChls-sample-epub.acsm?id=CsrODwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Das_Tabu_und_die_Ambivalenz_der_Gef%C3%BChls-sample-pdf.acsm?id=CsrODwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=CsrODwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "&quot;Das Tabu und die Ambivalenz der Gefühlsregungen&quot; von Sigmund Freud."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "bjoZyYpdVhQC",
#    "etag": "6ns/mIZZ+Bc",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/bjoZyYpdVhQC",
#    "volumeInfo": {
#     "title": "Neue Folge der Vorlesungen zur Einführung in die Psychoanalyse",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "BoD – Books on Demand",
#     "publishedDate": "2012",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783864037863"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3864037867"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 260,
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=bjoZyYpdVhQC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=bjoZyYpdVhQC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=bjoZyYpdVhQC&printsec=frontcover&dq=inauthor:freud&hl=&cd=14&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=bjoZyYpdVhQC&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Neue_Folge_der_Vorlesungen_zur_Einf%C3%BChru.html?hl=&id=bjoZyYpdVhQC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=bjoZyYpdVhQC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "TMrODwAAQBAJ",
#    "etag": "fQEz4V6c2JU",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/TMrODwAAQBAJ",
#    "volumeInfo": {
#     "title": "Der Wahn und die Träume in W. Jensens \"Gradiva\"",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Good Press",
#     "publishedDate": "2020-02-04",
#     "description": "\"Der Wahn und die Träume in W. Jensens \"Gradiva\"\" von Sigmund Freud. Veröffentlicht von Good Press. Good Press ist Herausgeber einer breiten Büchervielfalt mit Titeln jeden Genres. Von bekannten Klassikern, Belletristik und Sachbüchern bis hin zu in Vergessenheit geratenen bzw. noch unentdeckten Werken der grenzüberschreitenden Literatur, bringen wir Bücher heraus, die man gelesen haben muss. Jede eBook-Ausgabe von Good Press wurde sorgfältig bearbeitet und formatiert, um das Leseerlebnis für alle eReader und Geräte zu verbessern. Unser Ziel ist es, benutzerfreundliche eBooks auf den Markt zu bringen, die für jeden in hochwertigem digitalem Format zugänglich sind.",
#     "industryIdentifiers": [
#      {
#       "type": "OTHER",
#       "identifier": "EAN:4064066117009"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 188,
#     "printType": "BOOK",
#     "categories": [
#      "Fiction"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.1.1.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=TMrODwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=TMrODwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=TMrODwAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=15&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=TMrODwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=TMrODwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 1.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 1.0,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=TMrODwAAQBAJ&rdid=book-TMrODwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 1000000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 1000000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Der_Wahn_und_die_Tr%C3%A4ume_in_W_Jensens_Gr-sample-epub.acsm?id=TMrODwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Der_Wahn_und_die_Tr%C3%A4ume_in_W_Jensens_Gr-sample-pdf.acsm?id=TMrODwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=TMrODwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "&quot;Der Wahn und die Träume in W. Jensens &quot;Gradiva&quot;&quot; von Sigmund Freud."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "o97lWZ5L-SMC",
#    "etag": "leWdbw8HYZ4",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/o97lWZ5L-SMC",
#    "volumeInfo": {
#     "title": "Gesammelte Werke, Band 4",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Jazzybee Verlag",
#     "publishedDate": "2012",
# ...
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "qwMQDgAAQBAJ",
#    "etag": "cbBVImpxYKM",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/qwMQDgAAQBAJ",
#    "volumeInfo": {
#     "title": "Gesammelte Werke, Band 5",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Jazzybee Verlag",
#     "publishedDate": "2015-08-01",
#     "description": "Freud gilt als einer der einflussreichsten Denker des 20. Jahrhunderts; seine Theorien und Methoden werden bis heute kontrovers diskutiert. Dieser Band beinhaltet folgende Schriften: Die endliche und die unendliche Analyse, Die Frage der Laienanalyse, Die Traumdeutung, Die Zukunft einer Illusion, Drei Abhandlungen zur Sexualtheorie",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783849695293"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3849695298"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 596,
#     "printType": "BOOK",
#     "categories": [
#      "Psychology"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "0.1.0.0.preview.1",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=qwMQDgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=qwMQDgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=qwMQDgAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=36&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=qwMQDgAAQBAJ&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Gesammelte_Werke_Band_5.html?hl=&id=qwMQDgAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=qwMQDgAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Freud gilt als einer der einflussreichsten Denker des 20."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "XW4TAwAAQBAJ",
#    "etag": "EjklXXh7k18",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/XW4TAwAAQBAJ",
#    "volumeInfo": {
#     "title": "Totem und Tabu",
#     "authors": [
#      "S. Freud"
#     ],
#     "publisher": "Рипол Классик",
#     "publishedDate": "1956",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9785881485757"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "5881485750"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 188,
#     "printType": "BOOK",
#     "categories": [
#      "History"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.0.1.0.preview.1",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=XW4TAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=XW4TAwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=XW4TAwAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=37&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=XW4TAwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=XW4TAwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 3.64,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 3.02,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=XW4TAwAAQBAJ&rdid=book-XW4TAwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 3640000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 3020000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Totem_und_Tabu-sample-pdf.acsm?id=XW4TAwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=XW4TAwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "86d4DwAAQBAJ",
#    "etag": "G56R2GNXgs4",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/86d4DwAAQBAJ",
#    "volumeInfo": {
#     "title": "Vorlesungen zur Einführung in die Psychoanalyse",
#     "subtitle": "Sigmund-Freud-Reihe",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "andersseitig.de",
#     "publishedDate": "2017-11-30",
#     "description": "Alle Eigentümlichkeiten, durch welche diese Arbeit den Lesern des Buches auffallen wird, erklären sich aus den Bedingungen ihrer Entstehung. Es war nicht möglich, in der Darstellung die kühle Ruhe einer wissenschaftlichen Abhandlung zu wahren; vielmehr musste sich der Redner zur Aufgabe machen, die Aufmerksamkeit der Zuhörer während eines fast zweistündigen Vortrags nicht erlahmen zu lassen. Die Rücksicht auf die momentane Wirkung machte es unvermeidlich, dass derselbe Gegenstand eine wiederholte Behandlung fand, z. B. das eine Mal im Zusammenhang der Traumdeutung und dann später in dem der Neurosenprobleme. Die Anordnung des Stoffes brachte es auch mit sich, dass manche wichtige Themen, wie z. B. das des Unbewussten, nicht an einer einzigen Stelle erschöpfend gewürdigt werden konnten, sondern zu wiederholten Malen aufgenommen und wieder fallengelassen wurden, bis sich eine neue Gelegenheit ergab, etwas zu ihrer Kenntnis hinzuzufügen. Wer mit der psychoanalytischen Literatur vertraut ist, wird in dieser Einführung wenig finden, was ihm nicht aus anderen, weit ausführlicheren Veröffentlichungen bekannt sein könnte. Doch hat das Bedürfnis nach Abrundung und Zusammenfassung des Stoffes den Verfasser genötigt, in einzelnen Abschnitten (bei der ätiologie der Angst, den hysterischen Phantasien) auch bisher zurückgehaltenes Material heranzuziehen. S.F.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783961186532"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3961186537"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 696,
#     "printType": "BOOK",
#     "categories": [
#      "Psychology"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.4.2.0.preview.3",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=86d4DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=86d4DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=86d4DwAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=38&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=86d4DwAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=86d4DwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 4.5,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 3.38,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=86d4DwAAQBAJ&rdid=book-86d4DwAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 4500000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 3380000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true
#     },
#     "pdf": {
#      "isAvailable": true
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=86d4DwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Alle Eigentümlichkeiten, durch welche diese Arbeit den Lesern des Buches auffallen wird, erklären sich aus den Bedingungen ihrer Entstehung."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "JhyNDwAAQBAJ",
#    "etag": "ah9/Nwd2Dm0",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/JhyNDwAAQBAJ",
#    "volumeInfo": {
#     "title": "Die junge Psychoanalyse im Boudoir",
#     "publishedDate": "2019-04",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783643509147"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3643509146"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 208,
#     "printType": "BOOK",
#     "averageRating": 5.0,
#     "ratingsCount": 1,
#     "maturityRating": "MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=JhyNDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=JhyNDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=JhyNDwAAQBAJ&printsec=frontcover&dq=inauthor:freud&hl=&cd=39&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=JhyNDwAAQBAJ&dq=inauthor:freud&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Die_junge_Psychoanalyse_im_Boudoir.html?hl=&id=JhyNDwAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=JhyNDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Die Sache des Eros ist das wesentliche Anliegen der Psychoanalyse. Gegen alle Tendenzen der Glättung rückt die Psychoanalyse die Spannung zwischen dem Konflikthaften und dem Lustvollen der Sexualität ins Zentrum ihres Denkens."
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "J7dYb6wjr0IC",
#    "etag": "gSTEIB8mcpo",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/J7dYb6wjr0IC",
#    "volumeInfo": {
#     "title": "Massenpsychologie und Ich-Analyse",
#     "authors": [
#      "Sigmund Freud"
#     ],
#     "publisher": "Satzweiss.com",
#     "publishedDate": "2012-12-17",
#     "description": "Der Gegensatz von Individual- und Sozial- oder Massenpsychologie, der uns auf den ersten Blick als sehr bedeutsam erscheinen mag, verliert bei eingehender Betrachtung sehr viel von seiner Schärfe. Die Individualpsychologie ist zwar auf den einzelnen Menschen eingestellt und verfolgt, auf welchen Wegen derselbe die Befriedigung seiner Triebregungen zu erreichen sucht, allein sie kommt dabei nur selten, unter bestimmten Ausnahmsbedingungen, in die Lage, von den Beziehungen dieses Einzelnen zu anderen Individuen abzusehen. Im Seelenleben des Einzelnen kommt ganz regelmäßig der Andere als Vorbild, als Objekt, als Helfer und als Gegner in Betracht und die Individualpsychologie ist daher von Anfang an auch gleichzeitig Sozialpsychologie in diesem erweiterten, aber durchaus berechtigten Sinne...",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9783845011356"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "3845011351"
#      }
#     ],
#     "readingModes": {
#      "text": true,
#      "image": true
#     },
#     "pageCount": 84,
#     "printType": "BOOK",
#     "categories": [
#      "Psychology"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": true,
#     "contentVersion": "1.1.1.0.preview.3",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=J7dYb6wjr0IC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=J7dYb6wjr0IC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "de",
#     "previewLink": "http://books.google.ch/books?id=J7dYb6wjr0IC&printsec=frontcover&dq=inauthor:freud&hl=&cd=40&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=J7dYb6wjr0IC&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=J7dYb6wjr0IC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#      "amount": 2.0,
#      "currencyCode": "CHF"
#     },
#     "retailPrice": {
#      "amount": 2.0,
#      "currencyCode": "CHF"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=J7dYb6wjr0IC&rdid=book-J7dYb6wjr0IC&rdot=1&source=gbs_api",
#     "offers": [
#      {
#       "finskyOfferType": 1,
#       "listPrice": {
#        "amountInMicros": 2000000.0,
#        "currencyCode": "CHF"
#       },
#       "retailPrice": {
#        "amountInMicros": 2000000.0,
#        "currencyCode": "CHF"
#       },
#       "giftable": true
#      }
#     ]
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Massenpsychologie_und_Ich_Analyse-sample-epub.acsm?id=J7dYb6wjr0IC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "pdf": {
#      "isAvailable": true,
#      "acsTokenLink": "http://books.google.ch/books/download/Massenpsychologie_und_Ich_Analyse-sample-pdf.acsm?id=J7dYb6wjr0IC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=J7dYb6wjr0IC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Der Gegensatz von Individual- und Sozial- oder Massenpsychologie, der uns auf den ersten Blick als sehr bedeutsam erscheinen mag, verliert bei eingehender Betrachtung sehr viel von seiner Schärfe."
#    }
#   }
#  ]
# }

# %% [markdown]
# #### Status codes
#
# Responses contain information even without looking into the textual content. printing the response tells us the URL we requested, the date, its status, the content type and the size of the response object
#
# The most important for us is the status: it tells us whether our request has been successful: You can find a list of HTTP status codes here https://en.wikipedia.org/wiki/List_of_HTTP_status_codes.
# Or, you can always check HTTP Status Cats: https://www.flickr.com/photos/girliemac/sets/72157628409467125
#
# The most important status codes for us are:
#
# - successful call: code 200
# - client error: 4xx, e.g. 401: Unauthorized, 404: Not found
# - server error: 5xx, e.g. 500: Internal Server Error, 502: Bad Gateway

# %% [markdown]
# ### 2. Parsing json

# %% [markdown]
# 1. Using the previously defined function, query the book with isbn number 1904633684 and print the text of the result.

# %%
print(request_books_api("isbn", 1904633684))
# Out:
# {
#  "kind": "books#volumes",
#  "totalItems": 1,
#  "items": [
#   {
#    "kind": "books#volume",
#    "id": "tBasGxqDMbMC",
#    "etag": "1GU8jEcB/WU",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/tBasGxqDMbMC",
#    "volumeInfo": {
#     "title": "The Case-book of Sherlock Holmes",
#     "authors": [
#      "Arthur Conan Doyle"
#     ],
#     "publisher": "Collector's Library",
#     "publishedDate": "2004",
#     "description": "The Casebook of Sherlock Holmes contains Conan Doyle's last twelve stories about his great fictional detective. Compared with earlier collections these tales are darker, exploring such themes as treachery, mutilation and the terrible consequences of infidelity, and containing such gothic touches as a blood-sucking vampire and crypts at midnight. With an Afterword by David Stuart Davies, a Fellow of the Royal Literary Fund, and an authority on Sherlock Holmes. He has written the Afterwords for all the Collector's Library Holmes volumes.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "1904633684"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9781904633686"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": true
#     },
#     "pageCount": 304,
#     "printType": "BOOK",
#     "categories": [
#      "Detective and mystery stories"
#     ],
#     "averageRating": 3.5,
#     "ratingsCount": 23,
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "1.0.1.0.preview.1",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=tBasGxqDMbMC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=tBasGxqDMbMC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=tBasGxqDMbMC&printsec=frontcover&dq=isbn:1904633684&hl=&cd=1&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=tBasGxqDMbMC&dq=isbn:1904633684&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/The_Case_book_of_Sherlock_Holmes.html?hl=&id=tBasGxqDMbMC"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=tBasGxqDMbMC&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "Compared with earlier collections these tales are darker, exploring such themes as treachery, mutilation and the terrible consequences of infidelity, and containing such gothic touches as a blood-sucking vampire and crypts at midnight."
#    }
#   }
#  ]
# }

# %% [markdown]
# 2. Now load the previous response into a json object.:

# %%
# Send the request and save the json object
result = request_books_api("isbn", 1904633684)
json_result = json.loads(result)
print(json_result)
# Out:
# {'kind': 'books#volumes', 'totalItems': 1, 'items': [{'kind': 'books#volume', 'id': 'tBasGxqDMbMC', 'etag': '1GU8jEcB/WU', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/tBasGxqDMbMC', 'volumeInfo': {'title': 'The Case-book of Sherlock Holmes', 'authors': ['Arthur Conan Doyle'], 'publisher': "Collector's Library", 'publishedDate': '2004', 'description': "The Casebook of Sherlock Holmes contains Conan Doyle's last twelve stories about his great fictional detective. Compared with earlier collections these tales are darker, exploring such themes as treachery, mutilation and the terrible consequences of infidelity, and containing such gothic touches as a blood-sucking vampire and crypts at midnight. With an Afterword by David Stuart Davies, a Fellow of the Royal Literary Fund, and an authority on Sherlock Holmes. He has written the Afterwords for all the Collector's Library Holmes volumes.", 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1904633684'}, {'type': 'ISBN_13', 'identifier': '9781904633686'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 304, 'printType': 'BOOK', 'categories': ['Detective and mystery stories'], 'averageRating': 3.5, 'ratingsCount': 23, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '1.0.1.0.preview.1', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=tBasGxqDMbMC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=tBasGxqDMbMC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.ch/books?id=tBasGxqDMbMC&printsec=frontcover&dq=isbn:1904633684&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.ch/books?id=tBasGxqDMbMC&dq=isbn:1904633684&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Case_book_of_Sherlock_Holmes.html?hl=&id=tBasGxqDMbMC'}, 'saleInfo': {'country': 'CH', 'saleability': 'NOT_FOR_SALE', 'isEbook': False}, 'accessInfo': {'country': 'CH', 'viewability': 'PARTIAL', 'embeddable': True, 'publicDomain': False, 'textToSpeechPermission': 'ALLOWED', 'epub': {'isAvailable': False}, 'pdf': {'isAvailable': False}, 'webReaderLink': 'http://play.google.com/books/reader?id=tBasGxqDMbMC&hl=&printsec=frontcover&source=gbs_api', 'accessViewStatus': 'SAMPLE', 'quoteSharingAllowed': False}, 'searchInfo': {'textSnippet': 'Compared with earlier collections these tales are darker, exploring such themes as treachery, mutilation and the terrible consequences of infidelity, and containing such gothic touches as a blood-sucking vampire and crypts at midnight.'}}]}

# %% [markdown]
# 3. What are the highest level keys of the json object?

# %%
for key in json_result.keys():
    print(key)
# Out:
# kind
# totalItems
# items

# %% [markdown]
# 4. What is the type of the value of 'items' key?

# %%
print(type(json_result['items']))
# Out:
# <class 'list'>

# %% [markdown]
# 5. Parse the following information from the json object

# %%
### Total number of items returned by the request

print("Found items count : {}".format(jsn_result['totalItems']))


### Title of the book

for el in jsn_result["items"]:
    dic = el['volumeInfo']
    print("Title: {}".format(dic['title']))


### Authors of the book

for el in jsn_result["items"]:
    dic = el['volumeInfo']
    print("Authors: {}".format(dic['authors']))


### Date of publishing

for el in jsn_result["items"]:
    dic = el['volumeInfo']
    print("Date of publishing: {}".format(dic['publishedDate']))


### Page Count

for el in jsn_result["items"]:
    dic = el['volumeInfo']
    print("Page Count: {}".format(dic['pageCount']))
    
### Categories

for el in jsn_result["items"]:
    dic = el['volumeInfo']
    print("Categories: {}".format(dic['categories']))
    
### Average Rating

for el in jsn_result["items"]:
    dic = el['volumeInfo']
    print("Average Rating: {}".format(dic['averageRating']))

### Rating Count

for el in jsn_result["items"]:
    dic = el['volumeInfo']
    print("Rating Count: {}".format(dic['ratingsCount']))


### Is it avaliable as Epublication (Epub)

for el in jsn_result["items"]:
    dic = el['accessInfo']
    print("Availaible as Epublication: {}".format(dic['epub']['isAvailable']))
# Out:
# Found items count : 1
# Title: The Case-book of Sherlock Holmes
# Authors: ['Arthur Conan Doyle']
# Date of publishing: 2004
# Page Count: 304
# Categories: ['Detective and mystery stories']
# Average Rating: 3.5
# Rating Count: 23
# Availaible as Epublication: False

# %% [markdown]
# Unlike in the case of requesting books by IDs, the requests in which you search for author or title usually have more than one book as a result. Try searching for books that contain a specific word in their title.
#
# 6. Once you obtain the result of the request as a json object, loop through all books in the json and print out the **title** of all the books.

# %%
# Send request and save the json object
result2 = request_books_api("intitle", "connotation")
json_result2 = json.loads(result2)

# Loop through the books and print their title
cnt = 1
for el in json_result2["items"]:
    dic2 = el['volumeInfo']
    print("Title {}: {}".format(cnt, dic2['title']))
    cnt += 1
# Out:
# Title 1: Connotation and Meaning
# Title 2: Negative Connotation Among English Verbs with Marked Onsets
# Title 3: Connotation and Denotation in a Work of Film Art
# Title 4: A Discussion of Laterite Especially in Respect to the Original Connotation of the Term
# Title 5: The New Normal of China's Economy: Connotation and Measurement
# Title 6: The Effect of Restraint, Image Connotation and Image Type Upon Interference Scores in a Picture-word Interference Task
# Title 7: Denotation and Connotation in Strategic International Human Resource Management
# Title 8: The Reliability and Interrelational Characteristics of Rated Frequency, Pronunciability, and Affective Connotation for 100 Words
# Title 9: The Doctrine of Connotation and Denotation
# Title 10: Conflict's Connotation

# %% [markdown]
# 7. Now search for books with a category and print out the authors

# %%
# Send request and save the json object
result3 = request_books_api("subject", "cooking")
json_result3 = json.loads(result3)

# Print out the authors' names
cnt = 1
for el in jsn_result3["items"]:
    dic3 = el['volumeInfo']
    print("Author {}: {}".format(cnt, dic3['authors']))
    cnt += 1
# Out:
# Author 1: ['Karen Jean Matsko Hood']
# Author 2: ['John T. Edge']
# Author 3: ['Lisa Vanderpump']
# Author 4: ['Brier Tyler', 'Natalie Moir']
# Author 5: ['Joan Nathan']
# Author 6: ['Harley Pasternak, M.Sc.', 'Myatt Murphy']
# Author 7: ['Paul Hollywood']
# Author 8: ['David Perlmutter']
# Author 9: ['Alon Shaya']
# Author 10: ['Chris Ying', 'René Redzepi', 'MAD']

# %% [markdown]
# 8. Define a function that given an item in the json object (the meta information about one book) returns a list with the following attributes: `title, authors, publishedDate, pageCount, categories, averageRating, ratingsCount, epub`.
# <br>
# Note that **not** every book has all the features required. If a piece of information is missing, your code should write NaN instead in place of the value.

# %%
def parse_json(j):
    '''the function takes a book item as an input and returns a list of the extracted features'''
    
    # Get elements from json one by one, set NaN if not found
    for el in j["items"]:

        dic = el['volumeInfo']

        title = dic.get('title', 'NaN')
        authors = dic.get('authors', 'NaN')
        publishedDate = dic.get('publishedDate', 'NaN')
        pageCount = dic.get('pageCount', 'NaN')
        categories = dic.get('categories', 'NaN')
        averageRating = dic.get('averageRating', 'NaN')
        ratingsCount = dic.get('ratingsCount', 'NaN')
        epub = el['accessInfo']['epub']['isAvailable'] 
    
    return title, authors, publishedDate, pageCount, categories, averageRating, ratingsCount, epub

# Example:
result = request_books_api("isbn", 1904633684)
json_result = json.loads(result)
parse_json(jsn_result)
# Out:
# ('The Case-book of Sherlock Holmes',
#  ['Arthur Conan Doyle'],
#  '2004',
#  304,
#  ['Detective and mystery stories'],
#  3.5,
#  23,
#  False)

# %% [markdown]
# ### 3. New York Times API
#
# Your task in this exercise will be to compare the amount of Brexit, Trump and Corona related articles in the last 6 months, using an API that the New York Times provides.
#
# Start with creating an API key on the NYT API website. As you can see there are multiple functionalities/APIs that the NYT provides. For this exercise we will use the one that allows you to search among articles. so when you sign up for the API key, make sure to pick that one.
#
# Here's the documentation for using this API, it explains the syntacs of queries: https://developer.nytimes.com/docs/articlesearch-product/1/overview
#
# 1. How can you specify a keyword to search for in the URL?
# 2. How can you specify a date or multiple dates to search for?
# 3. Write a function that takes a query to the API as an input and returns the number of hits (number of article results) that this query returns.
# 4. How many results are in a response json by default? How would you collect all results for a specific search? Either write an example code that in fact collects all articles for a query (in an example that has more than one page of results) or explain in detail how you would automate this process. You can use the function you created in 3. to automatically determine how may pages you have to loop through.
#
# Now you have all the pieces together to write a function that collects all results for a specific topic (keyword) written on a specific date. Remember, that our original question was how the appearance of 3 topics changed over time in the last 6 months.
#
# 5. Loop through all dates in the last 6 months and figure out how many articles there were in each of the 3 topics. You can aggregate into weekly or monthly buckets. You can also include synonyms of the given words (e.g. "Covid-19" for "Corona") or also search other terms that interest you.
#
# Using the below code, you can do a visualization of your findings.
#
# Trick for pretty printing json:
# when dealing with large json objects and trying to understand them, it is often difficult to read them on the screen. Use pprint library to see a nicer version of these jsons. (from pprint import pprint, and pprint("hello world"))

# %% [markdown]
# #### Visualization
#
# To help you out with the visualization, we have created the code below. In the description of the function you can find instructions on how to use it. There is also an example of a call underneath the function.
#
# You need to give two parameters to the function. The first one is a dictionary where the keys are the three search query terms that you have used (given as a string); for each term there is one list with the number of queries per each time-block considered. The second parameter is a list of strings with the names of the time periods being considered.
#
# Important note: the lengths of the lists must match. It is assumed that for each query there is a vector having the number of hits per each period specified in the list of the second parameter. This means that the three lists in the dictionary and the list given as the second parameter must have equal lengths.

# %%
# This is a pre-implemented function for crating the visualisation
# You don't have to modify this

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

def plot_no_articles(dictionary_results, periods):
    '''
    Plots the statistics with the number of articles in the past month.
    
    dictionary_results = dictionary of the form query_term: [no_articles_for_period_1, no_articles_for_period_2, ...]
        e.g. {'Brexit':[250, 200], 'Trump':[100, 75], 'Corona':[300, 400]}
             if you group articles by month periods, and 
             you have looked only at the past two months, and
             there were 250 hits for Brexit in February, and 200 in March, and
             there were 100 hits for Trump in February, and 75 in March, and
             there were 300 hits for Corona in February, and 400 in March
    periods = list of time periods used for the investigation
        e.g. ['February', 'March']
             if you have considered the past two months
    '''
    d = dictionary_results
    labels = periods
    query_terms = list(d.keys())
    list_0 = d[query_terms[0]]
    list_1 = d[query_terms[1]]
    list_2 = d[query_terms[2]]
    
    # locations for labels
    x = np.arange(0, len(labels))
    # width per bar
    width = 0.3
    
    # Building the subplots
    fig, ax = plt.subplots(figsize=(18,5))
    rects1 = ax.bar(x - width, list_0, width, label=query_terms[0])
    rects2 = ax.bar(x, list_1, width, label=query_terms[1])
    rects3 = ax.bar(x + width, list_2, width, label=query_terms[2])

    # Labeling
    ax.set_xlabel('Time periods')
    ax.set_ylabel('Number of articles')
    ax.set_title('Number of articles by query')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.autoscale()
    xmin = -2*width
    xmax = max(np.arange(len(labels)))+2*width
    ymin = 0
    ymax = max(list_0+list_1+list_2)*1.1 
    ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))
    ax.legend(loc='best')


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() /2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)
    
    fig.autofmt_xdate()

    fig.tight_layout()

    plt.show()

# Below there is one example of how to use the above plot function
dict_results2 = {'Brexit':[250, 200], 'Trump':[100, 75], 'Corona':[300, 400]}
plot_no_articles(dict_results2, ['February', 'March'])

# %% [markdown]
# #### Your solution for the third exercise

# %%
### Code for task 3
#Write a function that takes a query 
#to the API as an input and returns the number of hits (number of article results)
#that this query returns

def no_of_hits(query):
    link = "https://api.nytimes.com/svc/search/v2/articlesearch.json?q={}&api-key=dBmWUQiOR9GytaCMGtCjl0WEQZMOhZJS".format(query)
    
    json_articles = json.loads(requests.get(link).text)
    
    return json_articles["response"]["meta"]["hits"]

# no_of_hits("Corona")

# no_of_hits("Trump")

# no_of_hits("Brexit")

# %%
### Code for task 4

# %%
### Code for task 5

# %% [markdown]
# Congratulations for completing the second notebook! Now it’s time for feedback.
# 1.	Pass your solution to the other pair in your group.
# 2.	Include your feedback in the other pair’s notebook. Don’t forget to add your names at the top.
# 3.	Return the notebook with feedback to the original pairs.
# 4.	Upload your notebook, with the feedback included by the other pair on OLAT.
#
# You can think of/suggest (among other things)
#  - improvements in the code (e.g. readability, efficiency)
#  - improvements in the answers (e.g. are they easy to understand, are they correct, how can they be improved?)
#  - point out differences (e.g. are there any differences between the responses of the two pairs? if yes what are they, what is the cause, and in which way can they be useful?)
#
# Not all suggestions about the type of feedback apply to all types of questions. Try to give feedback in a meaningful and constructive way.

# %%
# Below there is space for giving feedback. This space should be used only by the other pair in your group.

'''
Feedback here
'''
