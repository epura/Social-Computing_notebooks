# %% [markdown]
# # Using APIs

# %% [markdown]
# Please inlcude your names below
# Also, please edit the name of the file and include the names of the two(or three) people answering
#
# Pair answering the assignment: David Steiger, Tim Moser, Dominik Frauchiger
# Pair giving feedback: Eleonora Pura, Christian Skorski

# %%
import requests
import json
import os

# %% [markdown]
# ## 1. Google books
# ### Setting the request URL parameters
# You can set the parameters of the API request according to the documentation below. The first part of the request is always the same, and the "q" which stands for question will take various parameters. <br>
# More documentation can be found at: https://developers.google.com/books/docs/v1/using?hl=vi#ids
#
# <img src="parameters.png" width=80%> </img>

# %% [markdown]
# **Example**: `https://www.googleapis.com/books/v1/volumes?q=isbn:9780141909882` returns information about the book with the given ISBN number (Everything is illuminated by Jonathan Safran Foer).

# %% [markdown]
# **Exercise**
#
# 1. Using the above parameters create the following request URLs!
#     1. Requesting books that have "potter" in the title
#     2. Requesting books that have "doyle" as author
#     3. With isbn "1904633684"
#     4. With id "2bGdK8CRKoEC"
#     5. Second result page when searching books that has "detective" listed in the category list
#     6. Second result page when searching books that have "potter in the title but showing 40 results in one page, not 10.
# <br>
#
# Try and see whether they work with `requests.get()`!

# %%
result_A = 'https://www.googleapis.com/books/v1/volumes?q=title:potter'
result_B = 'https://www.googleapis.com/books/v1/volumes?q=autor:doyle'
result_C = 'https://www.googleapis.com/books/v1/volumes?q=isbn:1904633684'
result_D = 'https://www.googleapis.com/books/v1/volumes?q=id:2bGdK8CRKoEC'
result_E = 'https://www.googleapis.com/books/v1/volumes?q=subject:detective&startIndex=11'
result_F = 'https://www.googleapis.com/books/v1/volumes?q=title:potter&startIndex=41&maxResults=40'

#check with requests

# uncomment to check
requests.get(result_A).text
#requests.get(result_B).text
#requests.get(result_C).text
#requests.get(result_D).text
#requests.get(result_E).text
#requests.get(result_F).text

# works in the browser too
# Out:
# '{\n "kind": "books#volumes",\n "totalItems": 917,\n "items": [\n  {\n   "kind": "books#volume",\n   "id": "SJH8AgAAQBAJ",\n   "etag": "Bg8CVoMcibE",\n   "selfLink": "https://www.googleapis.com/books/v1/volumes/SJH8AgAAQBAJ",\n   "volumeInfo": {\n    "title": "Einführung in Apache Solr",\n    "authors": [\n     "Markus Klose",\n     "Daniel Wrigley"\n    ],\n    "publisher": "O\'Reilly Germany",\n    "publishedDate": "2014-02-23",\n    "description": "Eine leistungsfähige Volltextsuche ist heute auf Websites, in Online-Shops oder auch im Unternehmen nicht mehr Kür, sondern Pflicht. Gefragt ist eine flexible Suchtechnologie, die auf unterschiedlichsten Systemen genutzt werden kann. Hier kommt Apache Solr ins Spiel: Dieser Open-Source-Suchserver bietet Entwicklern auf Basis von Standard-Webtechnologien eine mächtige und dabei einfach zu integrierende und zu benutzende Search Engine. Einführung in Apache Solr bietet einen fundierten Einstieg in die Suchtechnologie: Der Leser wird in die Lage versetzt, eine individuelle Suchlösung auf Basis von Apache Solr aufzusetzen. Beschrieben wird, aus welchen Komponenten Solr sich zusammensetzt, wie die Indexierung konfiguriert und manipuliert werden kann und welche Einstellungsmöglichkeiten es für die Suche gibt. Mit zahlreichen Beispielkonfigurationen, Tipps und Pitfalls aus der Praxis der Autoren",\n    "industryIdentifiers": [\n     {\n      "type": "ISBN_13",\n      "identifier": "9783955614225"\n     },\n     {\n      "type": "ISBN_10",\n      "identifier": "3955614220"\n     }\n    ],\n    "readingModes": {\n     "text": false,\n     "image": true\n    },\n    "pageCount": 336,\n    "printType": "BOOK",\n    "categories": [\n     "Computers"\n    ],\n    "maturityRating": "NOT_MATURE",\n    "allowAnonLogging": false,\n    "contentVersion": "preview-1.0.0",\n    "imageLinks": {\n     "smallThumbnail": "http://books.google.com/books/content?id=SJH8AgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",\n     "thumbnail": "http://books.google.com/books/content?id=SJH8AgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"\n    },\n    "language": "de",\n    "previewLink": "http://books.google.ch/books?id=SJH8AgAAQBAJ&pg=PA75&dq=title:potter&hl=&cd=1&source=gbs_api",\n    "infoLink": "http://books.google.ch/books?id=SJH8AgAAQBAJ&dq=title:potter&hl=&source=gbs_api",\n    "canonicalVolumeLink": "https://books.google.com/books/about/Einf%C3%BChrung_in_Apache_Solr.html?hl=&id=SJH8AgAAQBAJ"\n   },\n   "saleInfo": {\n    "country": "CH",\n    "saleability": "NOT_FOR_SALE",\n    "isEbook": false\n   },\n   "accessInfo": {\n    "country": "CH",\n    "viewability": "PARTIAL",\n    "embeddable": true,\n    "publicDomain": false,\n    "textToSpeechPermission": "ALLOWED",\n    "epub": {\n     "isAvailable": false\n    },\n    "pdf": {\n     "isAvailable": false\n    },\n    "webReaderLink": "http://play.google.com/books/reader?id=SJH8AgAAQBAJ&hl=&printsec=frontcover&source=gbs_api",\n    "accessViewStatus": "SAMPLE",\n    "quoteSharingAllowed": false\n   },\n   "searchInfo": {\n    "textSnippet": "Sie hat aber den Nachteil, dass Sie Ihre Inhalte nicht unterschiedlich analysieren \\u003cbr\\u003e\\nlassen können, d. h., \\u003cb\\u003eTitel\\u003c/b\\u003e werden genauso ... Diese Schreibweise können Sie \\u003cbr\\u003e\\nauch im Lucene Query Parser verwenden: q=\\u003cb\\u003etitle\\u003c/b\\u003e:(harry \\u003cb\\u003epotter\\u003c/b\\u003e)^10.0 OR cat:(\\u003cbr\\u003e\\nharry&nbsp;..."\n   }\n  },\n  {\n   "kind": "books#volume",\n   "id": "n3vng7gyGCYC",\n   "etag": "xyRPa0zzzhk",\n   "selfLink": "https://www.googleapis.com/books/v1/volumes/n3vng7gyGCYC",\n   "volumeInfo": {\n    "title": "Harry Potter",\n    "publisher": "PediaPress",\n    "readingModes": {\n     "text": false,\n     "image": true\n    },\n    "printType": "BOOK",\n    "maturityRating": "NOT_MATURE",\n    "allowAnonLogging": false,\n    "contentVersion": "preview-1.0.0",\n    "imageLinks": {\n     "sma ...

# %% [markdown]
# 1G. Define a function that sends a request to the google books API with the URL parameters as inputs to the function. Try to incorporate as many as the variables as possible and output a URL according to the settings you want to have. Don't forget to write a docstring explaning how the function works. Docstrings are explanations to functions, describing the input, output, and purpose of the function. If you haven't used them before, you can find more examples for example at: https://www.geeksforgeeks.org/python-docstrings/

# %%
def request_books_api(value:str, field = "", options = {}):
    '''
    arg1: Use value to enter search-query.
    arg2: To precisie your query you can use this fields https://developers.google.com/books/docs/v1/using?hl=vi#ids or none.
    arg3: You can also append options as an dictionary.
    Returns all volumes containing your search-query.
    '''
    
    # appens : if string not empty
    if field: field += ":"
    
    # creates url
    url = "https://www.googleapis.com/books/v1/volumes?q=%s%s" % (field, value)
    
    # Appends possible options
    for key in options:
        url += "&%s=%s" % (key, options[key])

    return requests.get(url).text

# To test uncomment
#print(request_books_api("potter", "title"))
print(request_books_api("detective", "subject", {'startIndex': 11, 'maxResults': 40}))
#print(request_books_api("cat"))
# Out:
# {
#  "kind": "books#volumes",
#  "totalItems": 28,
#  "items": [
#   {
#    "kind": "books#volume",
#    "id": "xvH0swEACAAJ",
#    "etag": "eX51XNmBrt8",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/xvH0swEACAAJ",
#    "volumeInfo": {
#     "title": "The Forgotten Lands",
#     "authors": [
#      "Justin Warren"
#     ],
#     "publishedDate": "2017-07-22",
#     "description": "Dylan Harper is a young, up and coming detective with a point to prove. But when he and his mentor Detective Joe Gardella are summoned to the office of the Chief of Police and given an assignment that is outside their jurisdiction they sense that something is up. Sent across the country to investigate the disappearance of a small town newspaper reporter who hasn't been seen or heard from in four days, Harper and Gardella will be a long way from home and working on their own. But almost as soon as they arrive on the scene Harper becomes aware that someone is watching them. As the detectives begin to sift through the evidence and zero in on a suspect, strange things start to occur. Chasing down a lead late one night Harper glimpses a shadowy figure lurking in the fog and after a frantic search all he hears is an eerie laugh trailing off into the mist. The next morning Harper wakes to find his tyres slashed and then Gardella is called back to the city leaving Harper alone and exposed. When someone scrawls a mysterious set of numbers on the wall of Harper's hotel room it sends the case in a whole new direction and threatens to destroy his career before it's even truly begun.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "1521847630"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9781521847633"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 376,
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=xvH0swEACAAJ&dq=subject:detective&hl=&cd=12&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=xvH0swEACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/The_Forgotten_Lands.html?hl=&id=xvH0swEACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=xvH0swEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "BRiovwEACAAJ",
#    "etag": "5hbvoEHkKss",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/BRiovwEACAAJ",
#    "volumeInfo": {
#     "title": "Hollow City : the Second Novel of Miss Peregrine's Peculiar Children",
#     "authors": [
#      "Ransom Riggs"
#     ],
#     "publishedDate": "2014",
#     "description": "Jacob Portman and his newfound friends travel to war-torn 1940 London where they use their unusual talents to find a cure for Miss Peregrine, the beloved headmistress of their orphanage who has been trapped in the body of a bird.",
#     "industryIdentifiers": [
#      {
#       "type": "OTHER",
#       "identifier": "OCLC:1023778891"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "language": "en",
#     "previewLink": "http://books.google.ch/books?id=BRiovwEACAAJ&dq=subject:detective&hl=&cd=13&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=BRiovwEACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Hollow_City_the_Second_Novel_of_Miss_Per.html?hl=&id=BRiovwEACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=BRiovwEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "ymZDAQAAIAAJ",
#    "etag": "vbQY23JAT7o",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/ymZDAQAAIAAJ",
#    "volumeInfo": {
#     "title": "程一鳴回憶錄",
#     "authors": [
#      "程一鳴"
#     ],
#     "publishedDate": "1979",
#     "industryIdentifiers": [
#      {
#       "type": "OTHER",
#       "identifier": "UCAL:$B346878"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 115,
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=ymZDAQAAIAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=ymZDAQAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#     },
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=ymZDAQAAIAAJ&dq=subject:detective&hl=&cd=14&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=ymZDAQAAIAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E7%A8%8B%E4%B8%80%E9%B3%B4%E5%9B%9E%E6%86%B6%E9%8C%84.html?hl=&id=ymZDAQAAIAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=ymZDAQAAIAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "cgFrPgAACAAJ",
#    "etag": "9Il9qwWmry8",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/cgFrPgAACAAJ",
#    "volumeInfo": {
#     "title": "失控",
#     "authors": [
#      "张震"
#     ],
#     "publishedDate": "2008",
#     "description": "本书描写真实的人类社会,书写在美好安全的表象下弥漫着的阴谋、进攻和威胁,线索围绕着莘江市连续发生的几起命案展开。",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "7535438652"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9787535438652"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 350,
#     "printType": "BOOK",
#     "categories": [
#      "Chinese fiction"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=cgFrPgAACAAJ&dq=subject:detective&hl=&cd=15&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=cgFrPgAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E5%A4%B1%E6%8E%A7.html?hl=&id=cgFrPgAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=cgFrPgAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "sc1wAQAACAAJ",
#    "etag": "hVtxMp7ywDA",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/sc1wAQAACAAJ",
#    "volumeInfo": {
#     "title": "纯属虚构",
#     "authors": [
#      "Middle"
#     ],
#     "publishedDate": "2016",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9865607301"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789865607302"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 205,
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=sc1wAQAACAAJ&dq=subject:detective&hl=&cd=16&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=sc1wAQAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E7%BA%AF%E5%B1%9E%E8%99%9A%E6%9E%84.html?hl=&id=sc1wAQAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=sc1wAQAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "XAPlPAAACAAJ",
#    "etag": "Sl50yzs1AKk",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/XAPlPAAACAAJ",
#    "volumeInfo": {
#     "title": "Hero",
#     "authors": [
#      "白崎博史",
#      "Hiroshi Shirasaki",
#      "福田靖",
#      "沈燕翎"
#     ],
#     "publishedDate": "2001",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9574731855"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789574731855"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 321,
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=XAPlPAAACAAJ&dq=subject:detective&hl=&cd=17&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=XAPlPAAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/Hero.html?hl=&id=XAPlPAAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=XAPlPAAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "BBzstgAACAAJ",
#    "etag": "Qp2w4rDBwSk",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/BBzstgAACAAJ",
#    "volumeInfo": {
#     "title": "隱形縱火犯",
#     "authors": [
#      "顔煦之",
#      "Zong He"
#     ],
#     "publishedDate": "1998",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9620827791"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789620827792"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 75,
#     "printType": "BOOK",
#     "categories": [
#      "Criminal investigation"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-TW",
#     "previewLink": "http://books.google.ch/books?id=BBzstgAACAAJ&dq=subject:detective&hl=&cd=18&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=BBzstgAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E9%9A%B1%E5%BD%A2%E7%B8%B1%E7%81%AB%E7%8A%AF.html?hl=&id=BBzstgAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=BBzstgAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "yOv0AAAACAAJ",
#    "etag": "21dL0C/fkZs",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/yOv0AAAACAAJ",
#    "volumeInfo": {
#     "title": "象牙色的衣柜",
#     "subtitle": "爽香21岁的冬天",
#     "authors": [
#      "赤川次郎",
#      "叶蕙"
#     ],
#     "publishedDate": "2004",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9621788595"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789621788597"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 275,
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=yOv0AAAACAAJ&dq=subject:detective&hl=&cd=19&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=yOv0AAAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E8%B1%A1%E7%89%99%E8%89%B2%E7%9A%84%E8%A1%A3%E6%9F%9C.html?hl=&id=yOv0AAAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=yOv0AAAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "6FpNAAAACAAJ",
#    "etag": "nrQFPdyC8Ac",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/6FpNAAAACAAJ",
#    "volumeInfo": {
#     "title": "小偷, 单程票",
#     "authors": [
#      "赤川次郎",
#      "Cilang Chichuan",
#      "叶蕙"
#     ],
#     "publishedDate": "2003",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9621785669"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789621785664"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 245,
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=6FpNAAAACAAJ&dq=subject:detective&hl=&cd=20&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=6FpNAAAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E5%B0%8F%E5%81%B7_%E5%8D%95%E7%A8%8B%E7%A5%A8.html?hl=&id=6FpNAAAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=6FpNAAAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "Xom4wAEACAAJ",
#    "etag": "iRjZTG4BRm8",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/Xom4wAEACAAJ",
#    "volumeInfo": {
#     "title": "女王陛下的打工偵探",
#     "authors": [
#      "大澤在昌"
#     ],
#     "publishedDate": "2010",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9866562506"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789866562501"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 344,
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "panelizationSummary": {
#      "containsEpubBubbles": false,
#      "containsImageBubbles": false
#     },
#     "language": "zh-TW",
#     "previewLink": "http://books.google.ch/books?id=Xom4wAEACAAJ&dq=subject:detective&hl=&cd=21&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=Xom4wAEACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E5%A5%B3%E7%8E%8B%E9%99%9B%E4%B8%8B%E7%9A%84%E6%89%93%E5%B7%A5%E5%81%B5%E6%8E%A2.html?hl=&id=Xom4wAEACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=Xom4wAEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "Q_8YuQAACAAJ",
#    "etag": "apBGCwCrBSc",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/Q_8YuQAACAAJ",
#    "volumeInfo": {
#     "title": "櫻花色的短大衣",
#     "subtitle": "爽香34歲的秋天",
#     "authors": [
#      "赤川次郎",
#      "葉蕙"
#     ],
#     "publishedDate": "2010",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9882108822"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789882108820"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 261,
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-TW",
#     "previewLink": "http://books.google.ch/books?id=Q_8YuQAACAAJ&dq=subject:detective&hl=&cd=22&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=Q_8YuQAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E6%AB%BB%E8%8A%B1%E8%89%B2%E7%9A%84%E7%9F%AD%E5%A4%A7%E8%A1%A3.html?hl=&id=Q_8YuQAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=Q_8YuQAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "JUElAwAACAAJ",
#    "etag": "qlAL9SibMPk",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/JUElAwAACAAJ",
#    "volumeInfo": {
#     "title": "雪地消失的恶魔",
#     "authors": [
#      "赤川次郎",
#      "叶蕙"
#     ],
#     "publishedDate": "2006",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9882103235"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789882103238"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 267,
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=JUElAwAACAAJ&dq=subject:detective&hl=&cd=23&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=JUElAwAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E9%9B%AA%E5%9C%B0%E6%B6%88%E5%A4%B1%E7%9A%84%E6%81%B6%E9%AD%94.html?hl=&id=JUElAwAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=JUElAwAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "-gTArQEACAAJ",
#    "etag": "ARVr47nJpyw",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/-gTArQEACAAJ",
#    "volumeInfo": {
#     "title": "疯狂的下毒者",
#     "authors": [
#      "吉耶麦特-莱斯普朗迪-泰"
#     ],
#     "publishedDate": "2013",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "7533935624"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9787533935627"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=-gTArQEACAAJ&dq=subject:detective&hl=&cd=24&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=-gTArQEACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E7%96%AF%E7%8B%82%E7%9A%84%E4%B8%8B%E6%AF%92%E8%80%85.html?hl=&id=-gTArQEACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=-gTArQEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "bdcOjwEACAAJ",
#    "etag": "CG+BZ+L/F7M",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/bdcOjwEACAAJ",
#    "volumeInfo": {
#     "title": "查理日记",
#     "subtitle": "原始恐怖岛的追踪者",
#     "publishedDate": "2014",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "753997754X"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9787539977546"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "printType": "BOOK",
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=bdcOjwEACAAJ&dq=subject:detective&hl=&cd=25&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=bdcOjwEACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E6%9F%A5%E7%90%86%E6%97%A5%E8%AE%B0.html?hl=&id=bdcOjwEACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=bdcOjwEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "gUnZZwEACAAJ",
#    "etag": "+9mUeNrl6Y8",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/gUnZZwEACAAJ",
#    "volumeInfo": {
#     "title": "白骨之凄凄: 神秘山村",
#     "authors": [
#      "郎芳",
#      "郎芳 (中國文學)"
#     ],
#     "publishedDate": "2008",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9866514099"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789866514098"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "printType": "BOOK",
#     "categories": [
#      "Detective/Thriller"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=gUnZZwEACAAJ&dq=subject:detective&hl=&cd=26&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=gUnZZwEACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E7%99%BD%E9%AA%A8%E4%B9%8B%E5%87%84%E5%87%84_%E7%A5%9E%E7%A7%98%E5%B1%B1%E6%9D%91.html?hl=&id=gUnZZwEACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=gUnZZwEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "ClQqAAAACAAJ",
#    "etag": "5Ro0uAMMtpw",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/ClQqAAAACAAJ",
#    "volumeInfo": {
#     "title": "欲罢不能",
#     "subtitle": "现代女性情感和欲望的羊皮书",
#     "authors": [
#      "冯华"
#     ],
#     "publishedDate": "2003",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "7501429294"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9787501429295"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 302,
#     "printType": "BOOK",
#     "categories": [
#      "Detective"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=ClQqAAAACAAJ&dq=subject:detective&hl=&cd=27&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=ClQqAAAACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E6%AC%B2%E7%BD%A2%E4%B8%8D%E8%83%BD.html?hl=&id=ClQqAAAACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=ClQqAAAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   },
#   {
#    "kind": "books#volume",
#    "id": "-CnUZwEACAAJ",
#    "etag": "nJPH20QOTtk",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/-CnUZwEACAAJ",
#    "volumeInfo": {
#     "title": "白骨之凄凄: 千年肉身",
#     "authors": [
#      "郎芳",
#      "郎芳 (中國文學)"
#     ],
#     "publishedDate": "2009",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_10",
#       "identifier": "9866514080"
#      },
#      {
#       "type": "ISBN_13",
#       "identifier": "9789866514081"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "printType": "BOOK",
#     "categories": [
#      "Detective/Thriller"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "preview-1.0.0",
#     "language": "zh-CN",
#     "previewLink": "http://books.google.ch/books?id=-CnUZwEACAAJ&dq=subject:detective&hl=&cd=28&source=gbs_api",
#     "infoLink": "http://books.google.ch/books?id=-CnUZwEACAAJ&dq=subject:detective&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/%E7%99%BD%E9%AA%A8%E4%B9%8B%E5%87%84%E5%87%84_%E5%8D%83%E5%B9%B4%E8%82%89%E8%BA%AB.html?hl=&id=-CnUZwEACAAJ"
#    },
#    "saleInfo": {
#     "country": "CH",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "CH",
#     "viewability": "NO_PAGES",
#     "embeddable": false,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=-CnUZwEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "NONE",
#     "quoteSharingAllowed": false
#    }
#   }
#  ]
# }

# %% [markdown]
# #### Status codes
#
# Responses contain information even without looking into the textual content. printing the response tells us the URL we requested, the date, its status, the content type and the size of the response object
#
# The most important for us is the status: it tells us whether our request has been successful: You can find a list of HTTP status codes here https://en.wikipedia.org/wiki/List_of_HTTP_status_codes.
# Or, you can always check HTTP Status Cats: https://www.flickr.com/photos/girliemac/sets/72157628409467125
#
# The most important status codes for us are:
#
# - successful call: code 200
# - client error: 4xx, e.g. 401: Unauthorized, 404: Not found
# - server error: 5xx, e.g. 500: Internal Server Error, 502: Bad Gateway

# %% [markdown]
# ### 2. Parsing json

# %% [markdown]
# 1. Using the previously defined function, query the book with isbn number 1904633684 and print the text of the result.

# %%
book = request_books_api("1904633684", "isbn")

# %% [markdown]
# 2. Now load the previous response into a json object.:

# %%
js_book = json.loads(book)

# %% [markdown]
# 3. What are the highest level keys of the json object?

# %%
for key in js_book.keys():
    print(key)
# Out:
# kind
# totalItems
# items

# %% [markdown]
# 4. What is the type of the value of 'items' key?

# %%
print(type(js_book['items']))
# Out:
# <class 'list'>

# %% [markdown]
# 5. Parse the following information from the json object

# %%
### Total number of items returned by the request
print("Total Items: %s" % js_book['totalItems'])

### Title of the book
print("Book Title: %s" % js_book['items'][0]['volumeInfo'].get('title', "NaN"))


### Authors of the book
print("Book Authors: %s" % js_book['items'][0]['volumeInfo'].get('authors', "NaN"))

### Date of publishing
print("Date of publishing: %s" % js_book['items'][0]['volumeInfo'].get('publishedDate', "NaN"))

### Page Count
print("Page Count: %s" % js_book['items'][0]['volumeInfo'].get('pageCount', "NaN"))

### Categories
print("Categories: %s" % js_book['items'][0]['volumeInfo'].get('categories', "NaN"))

### Average Rating
print("Average Rating: %s" % js_book['items'][0]['volumeInfo'].get('averageRating', "NaN"))

### Rating Count
print("Rating Count: %s" % js_book['items'][0]['volumeInfo'].get('ratingsCount', "NaN"))

### Is it avaliable as Epublication (Epub)
print("Epublication? %s" % js_book['items'][0]['accessInfo']['epub']['isAvailable'])
# Out:
# Total Items: 1
# Book Title: The Case-book of Sherlock Holmes
# Book Authors: ['Arthur Conan Doyle']
# Date of publishing: 2004
# Page Count: 304
# Categories: ['Detective and mystery stories']
# Average Rating: 3.5
# Rating Count: 23
# Epublication? False

# %% [markdown]
# Unlike in the case of requesting books by IDs, the requests in which you search for author or title usually have more than one book as a result. Try searching for books that contain a specific word in their title.
#
# 6. Once you obtain the result of the request as a json object, loop through all books in the json and print out the **title** of all the books.

# %%
java_books = json.loads(request_books_api("Java", "title"))['items']
for java_book in java_books:
    print(java_book['volumeInfo']['title'])
# Out:
# Das Java-Tutorial
# Java Web Services in a Nutshell
# Pro XML Development with Java Technology
# Java Illuminated
# Advances in Data and Web Management
# Das Java 6 codebook
# Learn Java for Android Development
# Java RMI
# A Practical Guide to Localization
# Beginning Java Programming

# %% [markdown]
# 7. Now search for books with a category and print out the authors

# %%
java_books = json.loads(request_books_api("thriller", "subject"))['items']
for java_book in java_books:
    print(java_book['volumeInfo']['authors'])
# Out:
# ['Gary Botting']
# ['D. J. Adams']
# ['Ramlee Awang Murshid']
# ['Andrea Kane']
# ['Neal Shusterman']
# ['Ramlee Awang Murshid']
# ['David Docherty']
# ['William Mark']
# ['Stephen Hunter']
# ['Stephen Coonts']

# %% [markdown]
# 8. Define a function that given an item in the json object (the meta information about one book) returns a list with the following attributes: `title, authors, publishedDate, pageCount, categories, averageRating, ratingsCount, epub`.
# <br>
# Note that **not** every book has all the features required. If a piece of information is missing, your code should write NaN instead in place of the value.

# %%
def parse_json(js_book):
    '''the function takes a book item as an input and returns a list of the extracted features'''
    
    #print(js_book)

    ### Title of the book
    title = js_book['volumeInfo'].get('title', "NaN")

    ### Authors of the book
    authors = js_book['volumeInfo'].get('authors', "NaN")

    ### Date of publishing
    publishedDate = js_book['volumeInfo'].get('publishedDate', "NaN")

    ### Page Count
    pageCount = js_book['volumeInfo'].get('pageCount', "NaN")

    ### Categories
    categories = js_book['volumeInfo'].get('categories', "NaN")

    ### Average Rating
    averageRating = js_book['volumeInfo'].get('averageRating', "NaN")

    ### Rating Count
    ratingsCount = js_book['volumeInfo'].get('ratingsCount', "NaN")

    ### Is it avaliable as Epublication (Epub)
    epub = js_book['accessInfo']['epub']['isAvailable']
    
    return title, authors, publishedDate, pageCount, categories, averageRating, ratingsCount, epub

# To test uncomment
books = json.loads(request_books_api("Java", "title"))['items']
for book in books:
    print("Title: %s\nAuthors: %s\nPublished Date: %s\nPage Count: %s\nCategories: %s\nAverage Rating: %s\nRatings Count: %s\nEpub? %s\n"
    % parse_json(book))
# Out:
# Title: Das Java-Tutorial
# Authors: NaN
# Published Date: 2007
# Page Count: 734
# Categories: NaN
# Average Rating: NaN
# Ratings Count: NaN
# Epub? False
#
# Title: Java Web Services in a Nutshell
# Authors: ['Kim Topley']
# Published Date: 2003
# Page Count: 642
# Categories: ['Computers']
# Average Rating: 4.0
# Ratings Count: 1
# Epub? False
#
# Title: Pro XML Development with Java Technology
# Authors: ['Ajay Vohra']
# Published Date: 2007-02-01
# Page Count: 472
# Categories: ['Computers']
# Average Rating: 4.0
# Ratings Count: 3
# Epub? True
#
# Title: Java Illuminated
# Authors: ['Anderson']
# Published Date: 2018-01-15
# Page Count: 1204
# Categories: ['Medical']
# Average Rating: NaN
# Ratings Count: NaN
# Epub? False
#
# Title: Advances in Data and Web Management
# Authors: ['Guozhu Dong', 'Xuemin Lin', 'Wei Wang', 'Yun Yang', 'Jeffrey Xu Yu']
# Published Date: 2007-06-26
# Page Count: 898
# Categories: ['Computers']
# Average Rating: 5.0
# Ratings Count: 1
# Epub? False
#
# Title: Das Java 6 codebook
# Authors: ['Dirk Louis', 'Peter Müller']
# Published Date: 2007
# Page Count: 829
# Categories: NaN
# Average Rating: 4.5
# Ratings Count: 3
# Epub? False
#
# Title: Learn Java for Android Development
# Authors: ['Jeff Friesen']
# Published Date: 2010-12-28
# Page Count: 656
# Categories: ['Computers']
# Average Rating: NaN
# Ratings Count: NaN
# Epub? True
#
# Title: Java RMI
# Authors: ['William Grosso']
# Published Date: 2002
# Page Count: 545
# Categories: ['Computers']
# Average Rating: 4.0
# Ratings Count: 1
# Epub? False
#
# Title: A Practical Guide to Localization
# Authors: ['Bert Esselink']
# Published Date: 2000-09-15
# Page Count: 497
# Categories: ['Language Arts & Disciplines']
# Average Rating: 4.0
# Ratings Count: 1
# Epub? False
#
# Title: Beginning Java Programming
# Authors: ['Bart Baesens', 'Aimee Backiel', 'Seppe vanden Broucke']
# Published Date: 2015-02-17
# Page Count: 672
# Categories: ['Computers']
# Average Rating: NaN
# Ratings Count: NaN
# Epub? True

# %% [markdown]
# ### 3. New York Times API
#
# Your task in this exercise will be to compare the amount of Brexit, Trump and Corona related articles in the last 6 months, using an API that the New York Times provides.
#
# Start with creating an API key on the NYT API website. As you can see there are multiple functionalities/APIs that the NYT provides. For this exercise we will use the one that allows you to search among articles. so when you sign up for the API key, make sure to pick that one.
#
# Here's the documentation for using this API, it explains the syntacs of queries: https://developer.nytimes.com/docs/articlesearch-product/1/overview
#
# 1. How can you specify a keyword to search for in the URL?
# 2. How can you specify a date or multiple dates to search for?
# 3. Write a function that takes a query to the API as an input and returns the number of hits (number of article results) that this query returns.
# 4. How many results are in a response json by default? How would you collect all results for a specific search? Either write an example code that in fact collects all articles for a query (in an example that has more than one page of results) or explain in detail how you would automate this process. You can use the function you created in 3. to automatically determine how may pages you have to loop through.
#
# Now you have all the pieces together to write a function that collects all results for a specific topic (keyword) written on a specific date. Remember, that our original question was how the appearance of 3 topics changed over time in the last 6 months.
#
# 5. Loop through all dates in the last 6 months and figure out how many articles there were in each of the 3 topics. You can aggregate into weekly or monthly buckets. You can also include synonyms of the given words (e.g. "Covid-19" for "Corona") or also search other terms that interest you.
#
# Using the below code, you can do a visualization of your findings.
#
# Trick for pretty printing json:
# when dealing with large json objects and trying to understand them, it is often difficult to read them on the screen. Use pprint library to see a nicer version of these jsons. (from pprint import pprint, and pprint("hello world"))

# %% [markdown]
# #### Visualization
#
# To help you out with the visualization, we have created the code below. In the description of the function you can find instructions on how to use it. There is also an example of a call underneath the function.
#
# You need to give two parameters to the function. The first one is a dictionary where the keys are the three search query terms that you have used (given as a string); for each term there is one list with the number of queries per each time-block considered. The second parameter is a list of strings with the names of the time periods being considered.
#
# Important note: the lengths of the lists must match. It is assumed that for each query there is a vector having the number of hits per each period specified in the list of the second parameter. This means that the three lists in the dictionary and the list given as the second parameter must have equal lengths.

# %%
# This is a pre-implemented function for crating the visualisation
# You don't have to modify this

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

def plot_no_articles(dictionary_results, periods):
    '''
    Plots the statistics with the number of articles in the past month.
    
    dictionary_results = dictionary of the form query_term: [no_articles_for_period_1, no_articles_for_period_2, ...]
        e.g. {'Brexit':[250, 200], 'Trump':[100, 75], 'Corona':[300, 400]}
             if you group articles by month periods, and 
             you have looked only at the past two months, and
             there were 250 hits for Brexit in February, and 200 in March, and
             there were 100 hits for Trump in February, and 75 in March, and
             there were 300 hits for Corona in February, and 400 in March
    periods = list of time periods used for the investigation
        e.g. ['February', 'March']
             if you have considered the past two months
    '''
    d = dictionary_results
    labels = periods
    query_terms = list(d.keys())
    list_0 = d[query_terms[0]]
    list_1 = d[query_terms[1]]
    list_2 = d[query_terms[2]]
    
    # locations for labels
    x = np.arange(0, len(labels))
    # width per bar
    width = 0.3
    
    # Building the subplots
    fig, ax = plt.subplots(figsize=(18,5))
    rects1 = ax.bar(x - width, list_0, width, label=query_terms[0])
    rects2 = ax.bar(x, list_1, width, label=query_terms[1])
    rects3 = ax.bar(x + width, list_2, width, label=query_terms[2])

    # Labeling
    ax.set_xlabel('Time periods')
    ax.set_ylabel('Number of articles')
    ax.set_title('Number of articles by query')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.autoscale()
    xmin = -2*width
    xmax = max(np.arange(len(labels)))+2*width
    ymin = 0
    ymax = max(list_0+list_1+list_2)*1.1 
    ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))
    ax.legend(loc='best')


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() /2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)
    
    fig.autofmt_xdate()

    fig.tight_layout()

    plt.show()

# Below there is one example of how to use the above plot function
dict_results2 = {'Brexit':[250, 200], 'Trump':[100, 75], 'Corona':[300, 400]}
plot_no_articles(dict_results2, ['February', 'March'])

# %% [markdown]
# #### Your solution for the third exercise

# %%
import time

# %%
### Code for task 3
def number_of_hits(query:str):
    url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?q=%s&api-key=v2N2XOGrkcRVM2GGesxJOZwH0slWmGb4" % query
    json_req = json.loads(requests.get(url).text)
    return json_req['response']['meta']['hits']

# Uncomment to test
#print("Number of Hits: %s" % number_of_hits("Trump"))

# %%
### Code for task 4

# By default we get 10 results (0 to 9)

def get_all_results(query:str):
    url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?q=%s&page=0&api-key=v2N2XOGrkcRVM2GGesxJOZwH0slWmGb4" % query
    json_results = json.loads(requests.get(url).text)
    # API sais max is 200 (min is 0)
    for i in range (1, min(json_results['response']['meta']['hits']//10, 200)):
        url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?q=%s&page=%s&api-key=v2N2XOGrkcRVM2GGesxJOZwH0slWmGb4" % (query, i)
        
        if "fault" in json_results:
            print("Error")
            return json_results

        json_results['response']['docs'].extend(json.loads(requests.get(url).text)['response']['docs'])
        # a little delay to prevent quota-error
        time.sleep(2)
    return json_results

# Test - Takes up to 2*200sec! - Better not to run it, since you can't run the next one
#print(len(get_all_results("Trump")['results']['docs']))

# %%
### Code for task 5
from datetime import datetime, timedelta

queries = {"Trump": [], "Corona": [], "Brexit": []}

date = datetime.now()

# fence problem
date += timedelta(days=30)

# Goes 6 months back
for _ in range(0, 6):
    # subtracts a month
    date -= timedelta(days=30)
    str_date = date.strftime("%m")
    for query in queries:
        queries[query].append(number_of_hits("%s&fq=pub_month:(%s)" % (query, str_date)))
    # To prevent the quota limit exeed error
    time.sleep(10)

plot_no_articles(queries, ["March", "February", "January", "December", "November", "October"])

# %% [markdown]
# Congratulations for completing the second notebook! Now it’s time for feedback.
# 1.	Pass your solution to the other pair in your group.
# 2.	Include your feedback in the other pair’s notebook. Don’t forget to add your names at the top.
# 3.	Return the notebook with feedback to the original pairs.
# 4.	Upload your notebook, with the feedback included by the other pair on OLAT.
#
# You can think of/suggest (among other things)
#  - improvements in the code (e.g. readability, efficiency)
#  - improvements in the answers (e.g. are they easy to understand, are they correct, how can they be improved?)
#  - point out differences (e.g. are there any differences between the responses of the two pairs? if yes what are they, what is the cause, and in which way can they be useful?)
#
# Not all suggestions about the type of feedback apply to all types of questions. Try to give feedback in a meaningful and constructive way.

# %% [markdown]
# Below there is space for giving feedback. This space should be used only by the other pair in your group.

# %% [markdown]
# <p><b>1. When opening your notebook and at every autosave or save, the following error message appears:</b> </p>
#
#
# <p>
#
#     Notebook validation failed
#     An invalid Notebook may not function properly. The validation error was:
# </p>
#
# <p>
#
#     Notebook validation failed:
#
#        ['outputPrepend','outputPrepend','outputPrepend','outputPrepend', 'outputPrepend','outputPrepend'] has nonunique elements: </p>
#
# <p>
#
#     [
#      "outputPrepend",
#      "outputPrepend",
#      "outputPrepend",
#      "outputPrepend",
#      "outputPrepend",
#      "outputPrepend"
#     ]
#
# </p>
#
# <p><b>2. In exercise 1.1, you searched for books titled 'potter' instead of searching books with 'potter' as part of the title as specified;</b> </p>
# <p><b>3. In exercise 2.1, you had to print the result, but you only saved it in a variable;</b> </p>
# <p><b>4. We liked the effort you put into the formatting for the test of the function in the exercise 2.8 ;</b> </p>
# <p><b>5. Other than that, as in the first exercise, the code is well readable, well documented and works as expected.</b> </p>
